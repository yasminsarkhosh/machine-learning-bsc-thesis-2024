# %% [markdown]
# ### Objective of the Notebook:
# The notebook is designed for preprocessing and extracting structured information from a collection of MICCAI 2023 XML documents. This involves transforming the raw XML data into clean, organized formats suitable for analysis and further processing. Key operations include parsing XML for headers and related text, identifying specific content like cancer-related papers, and extracting meaningful insights through structured dataframes.
#
# ### Input Data Expected:
# The input for this notebook includes:
# - XML documents from MICCAI 2023, located at a predefined directory on the user's system.
# - These XML documents should already be formatted correctly and accessible to the script for reading and processing.
#
# ### Output Data/Files Generated:
# Outputs generated by this notebook include:
# - Structured CSV files or dataframes containing parsed and cleaned information from the XML documents.
# - A CSV file specifically aggregating cancer-related papers extracted from the XML data.
# - Various CSV files based on further refined categorizations (like patient mentions in the cancer-related papers).
#
# ### Assumptions or Important Notes:
# - The GROBID client must be running on the local machine via terminal to process the documents. This client is essential for extracting text from the XML documents.
# - XML documents are expected to follow a consistent structure that allows for automated parsing by the script.
# - Manual interventions were necessary for file renaming based on titles extracted from XML, implying the script assumes that each document can be uniquely identified by its title.
# - The script assumes the presence of specific headers and textual formats within the XML files for accurate parsing.
# - Error handling is minimal, so XML files should not contain corrupt data or unexpected formatting errors.

# %% [markdown]
# # Automated Extraction and Analysis of MICCAI 2023 XML Documents
# ***

# %%
#!pip install lxml

# %%
import os
import re
import pandas as pd
import numpy as np
from xml.etree import ElementTree as et
from lxml import etree 
from collections import Counter

# %%
def wrap_text(text, width=100):
    """
    A simple function to wrap text at a given width.
    """
    if pd.isnull(text):
        return text  # Handle NaN values
    
    wrapped_lines = []
    for paragraph in text.split('\n'):  # Splitting by existing newlines to preserve paragraph breaks
        line = ''
        for word in paragraph.split():
            if len(line) + len(word) + 1 > width:
                wrapped_lines.append(line)
                line = word
            else:
                line += (' ' + word if line else word)
        wrapped_lines.append(line)
    return '\n'.join(wrapped_lines)

# %%
from grobid_client.grobid_client import GrobidClient
client = GrobidClient(grobid_server='http://localhost:8070')
# Out:
# GROBID server is up and running

# %%
# 
process_file = '../miccai_papers' 

client.process('processFulltextDocument', process_file, output="./03MICCAI_notebook_GROBID_processed_volumes", force=True)

# %%
# For finding missing XML files in the processed volumes:
# vol6: paper_15.grobid.tei.xml
# process_file = '/Users/yasminsarkhosh/Documents/GitHub/machine-learning-bsc-thesis-2024/project_submission/00_project_notebook/miccai_papers/vol6' 
# client.process('processFulltextDocument', process_file, output="./06", force=True)

# vol7: paper_13.grobid.tei.xml
# process_file = '/Users/yasminsarkhosh/Documents/GitHub/machine-learning-bsc-thesis-2024/project_submission/00_project_notebook/miccai_papers/vol7' 
# client.process('processFulltextDocument', process_file, output="./07", force=True)

# %% [markdown]
# ### Renaming XML files by folder path
# ***

# %% [markdown]
# Error in Renaming two GROBID XML files: Manually corrections on two XML files

# %%
''' 
File #1.
FileNotFoundError: [Errno 2] No such file or directory: '03MICCAI_notebook_GROBID_processed_volumes/vol7/paper_44.grobid.tei.xml' 
-> '03MICCAI_notebook_GROBID_processed_volumes/vol7/Full_Image-Index_Remainder_Based_Single_Low-Dose_DR/CT_Self-supervised_Denoising.xml'

Solution: Removing "/CT_Self-supervised_Denoising" from the XML file in paper_44 in vol7 and save the updated version
Re-run the code block again

File #2
FileNotFoundError: [Errno 2] No such file or directory: '03MICCAI_notebook_GROBID_processed_volumes/vol9/paper_49.grobid.tei.xml' 
-> '03MICCAI_notebook_GROBID_processed_volumes/vol9/A_Patient-Specific_Self-supervised_Model_for_Automatic_X-Ray/CT_Registration.xml'

Solution: Removing "/CT_Registration" from the XML file in paper_49 in vol9 and save the updated version
Re-run the code block again
'''

# %%
# Rename_xml_files_in_folder(folder_path)
from pandas._libs import missing


def find_title(element):
    """Recursively search for the title element in the XML structure."""
    if 'title' in element.tag.lower() and element.text:
        return element.text.strip()
    for child in element:
        title = find_title(child)
        if title:
            return title
    return None

def rename_xml_files_in_folder(folder_path):
    """Rename XML files based on their title tags."""
    for filename in os.listdir(folder_path):
        if not filename.endswith('.xml'):  # Skip non-XML files
            continue
        
        file_path = os.path.join(folder_path, filename)
        try:
            tree = et.parse(file_path)
            root = tree.getroot()
            paper_title = find_title(root)
            if paper_title:
                new_filename = paper_title.replace(" ", "_") + '.xml'
                new_file_path = os.path.join(folder_path, new_filename)
                os.rename(file_path, new_file_path)
                print(f"Renamed '{filename}' to '{new_filename}'")
            else:
                print(f"Title not found in '{filename}'. Skipping.")
        except et.ParseError as e:
            print(f"Error parsing '{filename}': {e}")

# path = '03MICCAI_notebook_GROBID_processed_volumes'
# # # Rename the XML files in the sub folders of the output folders of the Grobid client
# for volume_number in range(1, 11):
#     folder_path = f'{path}/vol{volume_number}'
#     print(f"Processing '{folder_path}'...")
#     rename_xml_files_in_folder(folder_path)
# Out:
# Renamed '07/paper_13.grobid.tei.xml' to 'Medical_Image_Computing_and_Computer_Assisted_Intervention_–_MICCAI_2023.xml'
# Renamed '06/paper_15.grobid.tei.xml' to 'Medical_Image_Computing_and_Computer_Assisted_Intervention_–_MICCAI_2023.xml'

# %%
# Renaming the missing files 
missing_files = {'06/paper_15.grobid.tei.xml', '07/paper_13.grobid.tei.xml'}

for file_path in missing_files:
    tree = et.parse(file_path)
    root = tree.getroot()
    paper_title = find_title(root)
    if paper_title:
        new_filename = paper_title.replace(" ", "_") + '.xml'
        new_file_path = os.path.join(os.path.dirname(file_path), new_filename)
        os.rename(file_path, new_file_path)
        print(f"Renamed '{file_path}' to '{new_filename}'")
    else:
        print(f"Title not found in '{file_path}'. Skipping.")

# %% [markdown]
# ### Manually Renaming Paper titles
# ***

# %% [markdown]
# The .xpath() method with the string() function in XPath concatenates all text nodes within the current context. This method can retrieve all text within an element, including text in nested child elements.

# %%
path = "03MICCAI_notebook_GROBID_processed_volumes"

''' 
First run of the notebook resulted in manually renaming the XML files by: 

1. Localising the text in the Abstract tag in the XML files named "Medical_Image_Computing_and_Computer_Assisted_Intervention_–_MICCAI_2023.xml"
2. Searching for matching text in the original PDF files stored in the "miccai_papers" directory and related subdirectories
    2.a) if the text is found, the title of the paper is copied from the PDF file and used to rename the XML file
3. Rename the title of the XML file by localising the title tag in the XML file, 
    3.a) paste the title of the paper from the PDF file, and 
    3.b) save the updated XML file

File #1: Dual Conditioned Diffusion Models for Out-of-Distribution Detection: Application to Fetal Ultrasound Videos
file_path = path + '/vol1/Medical_Image_Computing_and_Computer_Assisted_Intervention_–_MICCAI_2023.xml'

Renamed to: 
'03MICCAI_notebook_GROBID_processed_volumes/vol1/
Dual_Conditioned_Diffusion_Models_for_Out-of-Distribution_Detection:_Application_to_Fetal_Ultrasound_Videos.xml'

File #2: COLosSAL: A Benchmark for Cold-Start Active Learning for 3D Medical Image Segmentation
file_path = path + '/vol2/Medical_Image_Computing_and_Computer_Assisted_Intervention_–_MICCAI_2023.xml'

Renamed to: 
'03MICCAI_notebook_GROBID_processed_volumes/vol2/COLosSAL:_A_Benchmark_for_Cold-Start_Active_Learning_for_3D_Medical_Image_Segmentation.xml'

File #3: Learnable Cross-modal Knowledge Distillation for Multi-modal Learning with Missing Modality
file_path = path + '/vol4/Medical_Image_Computing_and_Computer_Assisted_Intervention_–_MICCAI_2023.xml'
Renamed to:...... 

File #4: 
# file_path = path + '/vol6/Medical_Image_Computing_and_Computer_Assisted_Intervention_–_MICCAI_2023.xml'
# Renamed to:......

.........

File #6: 
file_path = path + '/vol9/Medical_Image_Computing_and_Computer_Assisted_Intervention_–_MICCAI_2023.xml'

Rename to: Pelphix: Surgical Phase Recognition from X-Ray Images in Percutaneous Pelvic Fixation
'03MICCAI_notebook_GROBID_processed_volumes/vol9/Pelphix:_Surgical_Phase_Recognition_from_X-Ray_Images_in_Percutaneous_Pelvic_Fixation.xml'
'''
# FIRST RUN - RENAMING THE XML FILES BASED ON THE TITLE TAGS:
########################################################################################

# Load and parse the XML file 
# file_path = path + '/vol1/Medical_Image_Computing_and_Computer_Assisted_Intervention_–_MICCAI_2023.xml'
# file_path = path + '/vol2/Medical_Image_Computing_and_Computer_Assisted_Intervention_–_MICCAI_2023.xml'
# file_path = path + '/vol4/Medical_Image_Computing_and_Computer_Assisted_Intervention_–_MICCAI_2023.xml'
# file_path = path + '/vol6/Medical_Image_Computing_and_Computer_Assisted_Intervention_–_MICCAI_2023.xml'
# file_path = path + '/vol7/Medical_Image_Computing_and_Computer_Assisted_Intervention_–_MICCAI_2023.xml'
# file_path = path + '/vol9/Medical_Image_Computing_and_Computer_Assisted_Intervention_–_MICCAI_2023.xml'


# SECOND RUN - RENAMING THE MISSING XML FILES BY SAME METHOD:
########################################################################################

''' 
2 unique titles missing, 1 in vol6 and vol7 each, where both files were named 
"Medical_Image_Computing_and_Computer_Assisted_Intervention_–_MICCAI_2023.xml" instead of the actual title
in the previous code block. 

The missing files are:
- vol6: A Multi-task Method for Immunofixation Electrophoresis Image Classification (paper_15)
- vol7: DMCVR: Morphology-Guided Diffusion Model for 3D Cardiac Volume Reconstruction (paper_13)

Now, we will rename the files based on the actual titles.
'''

# 2 unique titles missing, 1 in vol6 and vol7 each:
# vol6: A Multi-task Method for Immunofixation Electrophoresis Image Classification (paper_15)
#file_path = '06/Medical_Image_Computing_and_Computer_Assisted_Intervention_–_MICCAI_2023.xml'

# vol7: DMCVR: Morphology-Guided Diffusion Model for 3D Cardiac Volume Reconstruction (paper_13)
# file_path = '07/Medical_Image_Computing_and_Computer_Assisted_Intervention_–_MICCAI_2023.xml'

########################################################################################

# Load and parse the XML file
tree = et.parse(file_path)
root = tree.getroot()

# Since XML namespaces can complicate direct tag access, we find the title tag dynamically.
# This approach is based on the assumption that titles are relatively unique in structure.

# Attempt to extract the paper title. This might need adjustments based on the actual structure.
title = None
for elem in root.iter():
    if 'title' in elem.tag.lower():
        title = elem.text
        break

title_clean = title.strip().replace(" ", "_") if title else "Untitled_Document"

# Attempt a more generic search for the title, considering common patterns in scholarly articles
# We'll look for title elements that might be nested within other elements (like "titleStmt" or "fileDesc" in TEI format)

def find_title(element):
    """
    Recursively search for the title element in the XML structure.
    """
    if 'title' in element.tag.lower() and element.text:
        return element.text.strip()
    for child in element:
        title = find_title(child)
        if title:
            return title
    return None

# Attempt to find the title using the recursive search
paper_title = find_title(root)
paper_title_clean = paper_title.replace(" ", "_") if paper_title else "Untitled_Document"


# Define the new file path with the clean title
new_file_path = os.path.join(os.path.dirname(file_path), f"{paper_title_clean}.xml")

# Rename the file
os.rename(file_path, new_file_path)

new_file_path
# Out:
# '07/DMCVR:_Morphology-Guided_Diffusion_Model_for_3D_Cardiac_Volume_Reconstruction.xml'

# %%
from lxml import etree 
def parse_xml_and_extract_headers(file_path):
    tree = etree.parse(file_path)
    root = tree.getroot()
    ns = {'tei': 'http://www.tei-c.org/ns/1.0'}

    # Extract the paper title by XPath in the XML's structure
    paper_title_element = root.find('.//tei:title', ns)
    paper_title = paper_title_element.text if paper_title_element is not None else "No Title Found"

    headers = root.xpath('//tei:head', namespaces=ns)
    print(f"Found {len(headers)} headers in '{paper_title}'")
    
    data = []
    for header in headers:
        # Use XPath string() function to get all text within the <p> tags, including nested elements
        text_content = ''.join(header.getparent().xpath('.//tei:p//text()', namespaces=ns))
        data.append({
            'Paper Title': paper_title,
            'Header Number': header.get('n'),
            'Header Title': header.text,
            'Text': text_content  # Updated to use text_content
        })

    df = pd.DataFrame(data, columns=['Paper Title', 'Header Number', 'Header Title', 'Text'])
    return df

def process_xml_folder(folder_path):
    all_data_frames = []
    for file_name in os.listdir(folder_path):
        if file_name.endswith(".xml"):
            file_path = os.path.join(folder_path, file_name)
            df = parse_xml_and_extract_headers(file_path)
            all_data_frames.append(df)

    if all_data_frames:
        final_df = pd.concat(all_data_frames, ignore_index=True)
    else:
        final_df = pd.DataFrame()

    return final_df
# Folder path - where XML files are be stored 
folder_path = '03MICCAI_notebook_GROBID_processed_volumes/*'

output_folder = '03MICCAI_notebook_GROBID_dataframes'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# # Process the folder and create a DataFrame with all headers
for volume_number in range(1, 11):
    folder_path = f'{path}/vol{volume_number}'
    print(f"Creating a DataFrame with Extracted Data From'{folder_path}'...")
    df_headers = process_xml_folder(folder_path)
    df_headers.to_csv(f"03MICCAI_notebook_GROBID_dataframes/03MICCAI_notebook_df_vol{volume_number}_headers.csv", index=False)
# Out:
# Creating a DataFrame with Extracted Data From'03MICCAI_notebook_GROBID_processed_volumes/vol1'...
# Found 13 headers in 'AMAE: Adaptation of Pre-trained Masked Autoencoder for Dual-Distribution Anomaly Detection in Chest X-Rays'
# Found 19 headers in 'Unsupervised Domain Adaptation for Anatomical Landmark Detection'
# Found 13 headers in 'CT-Guided, Unsupervised Super-Resolution Reconstruction of Single 3D Magnetic Resonance Image'
# Found 18 headers in 'Multi-scale Cross-restoration Framework for Electrocardiogram Anomaly Detection'
# Found 12 headers in 'Multi-modal Variational Autoencoders for Normative Modelling Across Multiple Imaging Modalities'
# Found 18 headers in 'Dense Transformer based Enhanced Coding Network for Unsupervised Metal Artifact Reduction'
# Found 22 headers in 'MedIM: Boost Medical Image Representation via Radiology Report-Guided Masking'
# Found 22 headers in 'Medical Image Computing and Computer Assisted Intervention – MICCAI 2023'
# Found 17 headers in 'Unsupervised Domain Transfer with Conditional Invertible Neural Networks'
# Found 19 headers in 'Anatomy-Driven Pathology Detection on Chest X-rays'
# Found 16 headers in 'Self-supervised Learning for Physiologically-Based Pharmacokinetic Modeling in Dynamic PET'
# Found 15 headers in 'Foundation Ark: Accruing and Reusing Knowledge for Superior and Robust Performance'
# Found 12 headers in 'LOTUS: Learning to Optimize Task-Based US Representations'
# Found 18 headers in 'Combating Medical Label Noise via Robust Semi-supervised Contrastive Learning'
# Found 18 headers in 'AME-CAM: Attentive Multiple-Exit CAM for Weakly Supervised Segmentation on MRI Brain Tumor'
# Found 13 headers in 'Correlation-Aware Mutual Learning for Semi-supervised Medical Image Segmentation'
# Found 12 headers in 'Multi-IMU with Online Self-consistency for Freehand 3D Ultrasound Reconstruction'
# Found 19 headers in 'Masked Vision and Language Pre-training with Unimodal and Multimodal Contrastive Losses for Medical Visual Question Answering'
# Found 17 headers in 'Inter-slice Consistency for Unpaired Low-Dose CT Denoising Using Boosted Contrastive Learning'
# Found 13 headers in 'You’ve Got Two Teachers: Co-evolutionary Image and Report Distillation for Semi-supervised Anatomical Abnormality Detection in Chest X-Ray'
# Found 20 headers in 'Modularity-Constrained Dynamic Representation Learning for Interpretable Brain Disorder Analysis with Functional MRI'
# Found 12 headers in 'Weakly-Supervised Positional Contrastive Learning: Application to Cirrhosis Classification'
# Found 16 headers in 'Unsupervised 3D Out-of-Distribution Detection with Latent Diffusion Models'
# Found 15 headers in 'Unsupervised Discovery of 3D Hierarchical Structure with Generative Diffusion Features'
# Found 17 headers in 'MDA-SR: Multi-level Domain Adaptation Super-Resolution for Wireless Capsule Endoscopy Images'
# Found 19 headers in 'S 2 ME: Spatial-Spectral Mutual Teaching and Ensemble Learning for Scribble-Supervised Polyp Segmentation'
# Found 18 headers in 'Graph Convolutional Network with Morphometric Similarity Networks for Schizophrenia Classification'
# Found 23 headers in 'M-FLAG: Medical Vision-Language Pre-training with Frozen Language Models and Latent Space Geometry Optimization'
# Found 17 headers in 'Tracking Adaptation to Improve SuperPoint for 3D Reconstruction in Endoscopy'
# Found 21 headers in 'Knowledge Boosting: Rethinking Medical Contrastive Vision-Language Pre-training'
# Found 14 headers in 'Deblurring Masked Autoencoder Is Better Recipe for Ultrasound Image Recognition'
# Found 9 headers in 'Black-box Domain Adaptative Cell Segmentation via Multi-source Distillation'
# Found 15 headers in 'Additional Positive Enables Better Representation Learning for Medical Images'
# Found 19 headers in 'Self-Supervised Domain Adaptive Segmentation of Breast Cancer via Test-Time Fine-Tuning'
# Found 16 headers in 'Decoupled Consistency for Semi-supervised Medical Image Segmentation'
# Found 15 headers in 'PET-Diffusion: Unsupervised PET Enhancement Based on the Latent Diffusion Model'
# Found 11 headers in '3D Arterial Segmentation via Single 2D Projections and Depth Supervision in Contrast-Enhanced CT Images'
# Found 18 headers in 'Mesh2SSM: From Surface Meshes to Statistical Shape Models of Anatomy'
# Found 19 headers in 'Cross-Adversarial Local Distribution Regularization for Semi-supervised Medical Image Segmentation'
# Found 18 headers in 'Infusing Physically Inspired Known Operators in Deep Models of Ultrasound Elastography'
# Found 13 headers in 'Domain Adaptation for Medical Image Segmentation Using Transformation-Invariant Self-training'
# Found 19 headers in 'SLPD: Slide-Level Prototypical Distillation for WSIs'
# Found 15 headers in 'Masked Frequency Consistency for Domain-Adaptive Semantic Segmentation of Laparoscopic Images'
# Found 14 headers in 'Can Point Cloud Networks Learn Statistical Shape Models of Anatomies?'
# Found 12 headers in 'PROnet: Point Refinement Using Shape-Guided Offset Map for Nuclei Instance Segmentation'
# Found 13 headers in 'Many Tasks Make Light Work: Learning to Localise Medical Anomalies from Multiple Synthetic Tasks'
# Found 14 headers in 'Improved Multi-shot Diffusion-Weighted MRI with Zero-Shot Self-supervised Learning Reconstruction'
# Found 13 headers in 'Image2SSM: Reimagining Statistical Shape Models from Images with Radial Basis Functions'
# Found 16 headers in 'TPRO: Text-Prompting-Based Weakly Supervised Histopathology Tissue Segmentation'
# Found 16 headers in 'LSOR: Longitudinally-Consistent Self-Organized Representation Learning'
# Found 8 headers in 'VesselVAE: Recursive Variational Autoencoders for 3D Blood Vessel Synthesis'
# Found 15 headers in 'A Small-Sample Method with EEG Signals Based on Abductive Learning for Motor Imagery Decoding'
# Found 13 headers in 'Weakly Supervised Lesion Localization of Nascent Geographic Atrophy in Age-Related Macular Degeneration'
# Found 24 headers in 'MetaLR: Meta-tuning of Learning Rates for Transfer Learning in Medical Imaging'
# Found 18 headers in 'Multi-modal Semi-supervised Evidential Recycle Framework for Alzheimer’s Disease Classification'
# Found 16 headers in 'DAS-MIL: Distilling Across Scales for MIL Classification of Histological WSIs'
# Found 17 headers in 'An Auto-Encoder to Reconstruct Structure with Cryo-EM Images via Theoretically Guaranteed Isometric Latent Space, and Its Application for Automatically Computing the Conformational Pathway'
# Found 13 headers in 'Pick the Best Pre-trained Model: Towards Transferability Estimation for Medical Image Segmentation'
# Found 18 headers in 'Modeling Alzheimers’ Disease Progression from Multi-task and Self-supervised Learning Perspective with Brain Networks'
# Found 16 headers in 'vox2vec: A Framework for Self-supervised Contrastive Learning of Voxel-Level Representations in Medical Images'
# Found 21 headers in 'Multi-Target Domain Adaptation with Prompt Learning for Medical Image Segmentation'
# Found 22 headers in 'Spectral Adversarial MixUp for Few-Shot Unsupervised Domain Adaptation'
# Found 13 headers in 'UOD: Universal One-Shot Detection of Anatomical Landmarks'
# Found 14 headers in 'Source-Free Domain Adaptive Fundus Image Segmentation with Class-Balanced Mean Teacher'
# Found 24 headers in 'MedGen3D: A Deep Generative Framework for Paired 3D Image and Mask Generation'
# Found 14 headers in 'PET Image Denoising with Score-Based Diffusion Probabilistic Models'
# Found 18 headers in 'CL-ADDA: Contrastive Learning with Amplitude-Driven Data Augmentation for fMRI-Based Individualized Predictions'
# Found 10 headers in 'Cross-Dataset Adaptation for Instrument Classification in Cataract Surgery Videos'
# Found 18 headers in 'Gall Bladder Cancer Detection from US Images with only Image Level Labels'
# Found 18 headers in 'Structured State Space Models for Multiple Instance Learning in Digital Pathology'
# Found 17 headers in 'Automatic Retrieval of Corresponding US Views in Longitudinal Examinations'
# Found 17 headers in 'Multi-scale Self-Supervised Learning for Longitudinal Lesion Tracking with Optional Supervision'
# Found 17 headers in 'Geometry-Invariant Abnormality Detection'
# Creating a DataFrame with Extracted Data From'03MICCAI_notebook_GROBID_processed_volumes/vol2'...
# Found 9 headers in 'Interpretable Medical Image Classification Using Prototype Learning and Privileged Information'
# Found 17 headers in 'Mixing Temporal Graphs with MLP for Longitudinal Brain Connectome Analysis'
# Found 13 headers in 'Attentive Deep Canonical Correlation Analysis for Diagnosing Alzheimer’s Disease Using Multimodal Imaging Genetics'
# Found 13 headers in 'NeuroExplainer: Fine-Grained Attention Decoding to Uncover Cortical Development Patterns of Preterm Infants'
# Found 14 headers in 'Incremental Learning for Heterogeneous Structure Segmentation in Brain Tumor MRI'
# Found 22 headers in 'ArSDM: Colonoscopy Images Synthesis with Adaptive Refinement Semantic Diffusion Models'
# Found 14 headers in 'Synthetic Augmentation with Large-Scale Unconditional Pre-training'
# Found 12 headers in 'Learning Transferable Object-Centric Diffeomorphic Transformations for Data Augmentation in Medical Image Segmentation'
# Found 19 headers in 'Few Shot Medical Image Segmentation with Cross Attention Transformer'
# Found 20 headers in 'Rethinking Semi-Supervised Federated Learning: How to Co-train Fully-Labeled and Fully-Unlabeled Client Imaging Data'
# Found 13 headers in 'FedContrast-GPA: Heterogeneous Federated Optimization via Local Contrastive Learning and Global Process-Aware Aggregation'
# Found 17 headers in 'Class Specific Feature Disentanglement and Text Embeddings for Multi-label Generalized Zero Shot CXR Classification'
# Found 18 headers in 'CXR-CLIP: Toward Large Scale Chest X-ray Language-Image Pre-training'
# Found 15 headers in 'Distilling BlackBox to Interpretable Models for Efficient Transfer Learning'
# Found 11 headers in 'Longitudinal Multimodal Transformer Integrating Imaging and Latent Clinical Signatures from Routine EHRs for Pulmonary Nodule Classification'
# Found 17 headers in 'EdgeAL: An Edge Estimation Based Active Learning Approach for OCT Segmentation'
# Found 12 headers in 'Partially Supervised Multi-organ Segmentation via Affinity-Aware Consistency Learning and Cross Site Feature Alignment'
# Found 14 headers in 'Prediction of Cognitive Scores by Joint Use of Movie-Watching fMRI Connectivity and Eye Tracking via Attention-CensNet'
# Found 17 headers in 'Centroid-Aware Feature Recalibration for Cancer Grading in Pathology Images'
# Found 15 headers in 'Explaining Massive-Training Artificial Neural Networks in Medical Image Analysis Task Through Visualizing Functions Within the Models'
# Found 13 headers in 'FeSViBS: Federated Split Learning of Vision Transformer with Block Sampling'
# Found 15 headers in 'Spatiotemporal Hub Identification in Brain Network by Learning Dynamic Graph Embedding on Grassmannian Manifold'
# Found 17 headers in 'TransLiver: A Hybrid Transformer Model for Multi-phase Liver Lesion Classification'
# Found 17 headers in 'Adaptive Region Selection for Active Learning in Whole Slide Image Semantic Segmentation'
# Found 17 headers in 'Aneurysm Pose Estimation with Deep Learning'
# Found 18 headers in 'Localized Questions in Medical Visual Question Answering'
# Found 15 headers in 'PLD-AL: Pseudo-label Divergence-Based Active Learning in Carotid Intima-Media Segmentation for Ultrasound Images'
# Found 11 headers in 'Medical Image Computing and Computer Assisted Intervention – MICCAI 2023'
# Found 15 headers in 'Federated Uncertainty-Aware Aggregation for Fundus Diabetic Retinopathy Staging'
# Found 18 headers in 'Debiasing Medical Visual Question Answering via Counterfactual Training'
# Found 17 headers in 'FedIIC: Towards Robust Federated Learning for Class-Imbalanced Medical Image Classification'
# Found 8 headers in 'Explainable Image Classification with Improved Trustworthiness for Tissue Characterisation'
# Found 15 headers in 'L3DMC: Lifelong Learning Using Distillation via Mixed-Curvature Space'
# Found 18 headers in 'An Interpretable and Attention-Based Method for Gaze Estimation Using Electroencephalography'
# Found 21 headers in 'Adaptive Multi-scale Online Likelihood Network for AI-Assisted Interactive Segmentation'
# Found 15 headers in 'Adapter Learning in Pretrained Feature Extractor for Continual Learning of Diseases'
# Found 16 headers in 'Client-Level Differential Privacy via Adaptive Intermediary in Federated Medical Imaging'
# Found 16 headers in 'Frequency Domain Adversarial Training for Robust Volumetric Medical Segmentation'
# Found 14 headers in 'Reconstructing the Hemodynamic Response Function via a Bimodal Transformer'
# Found 12 headers in 'Weakly Supervised Medical Image Segmentation via Superpixel-Guided Scribble Walking and Class-Wise Contrastive Regularization'
# Found 19 headers in 'Continual Learning for Abdominal Multi-organ and Tumor Segmentation'
# Found 15 headers in 'Right for the Wrong Reason: Can Interpretable ML Techniques Detect Spurious Correlations?'
# Found 8 headers in 'Efficient Subclass Segmentation in Medical Images'
# Found 19 headers in 'FedSoup: Improving Generalization and Personalization in Federated Learning via Selective Model Interpolation'
# Found 15 headers in 'Prediction of Infant Cognitive Development with Cortical Surface-Based Multimodal Learning'
# Found 14 headers in 'Category-Independent Visual Explanation for Medical Deep Network Understanding'
# Found 10 headers in 'Inflated 3D Convolution-Transformer for Weakly-Supervised Carotid Stenosis Grading with Ultrasound Videos'
# Found 18 headers in 'Towards AI-Driven Radiology Education: A Self-supervised Segmentation-Based Framework for High-Precision Medical Image Editing'
# Found 23 headers in 'Localized Region Contrast for Enhancing Self-supervised Learning in Medical Image Segmentation'
# Found 18 headers in 'An Explainable Geometric-Weighted Graph Attention Network for Identifying Functional Networks Associated with Gait Impairment'
# Found 16 headers in 'FedGrav: An Adaptive Federated Aggregation Algorithm for Multi-institutional Medical Image Segmentation'
# Found 17 headers in 'Joint Optimization of a $$\beta $$-VAE for ECG Task-Specific Feature Extraction'
# Found 15 headers in 'Partial Vessels Annotation-Based Coronary Artery Segmentation with Self-training and Prototype Learning'
# Found 13 headers in 'Faithful Synthesis of Low-Dose Contrast-Enhanced Brain MRI Scans Using Noise-Preserving Conditional GANs'
# Found 16 headers in 'SATTA: Semantic-Aware Test-Time Adaptation for Cross-Domain Medical Image Segmentation'
# Found 16 headers in 'A Spatial-Temporal Deformable Attention Based Framework for Breast Lesion Detection in Videos'
# Found 16 headers in 'Reveal to Revise: An Explainable AI Life Cycle for Iterative Bias Correction of Deep Models'
# Found 9 headers in 'A Flexible Framework for Simulating and Evaluating Biases in Deep Learning-Based Medical Image Analysis'
# Found 19 headers in 'Physics-Based Decoding Improves Magnetic Resonance Fingerprinting'
# Found 19 headers in 'DeDA: Deep Directed Accumulator'
# Found 14 headers in 'OpenAL: An Efficient Deep Active Learning Framework for Open-Set Pathology Image Classification'
# Found 14 headers in 'Transferability-Guided Multi-source Model Adaptation for Medical Image Segmentation'
# Found 15 headers in 'One-Shot Federated Learning on Medical Data Using Knowledge Distillation with Image Synthesis and Client Model Adaptation'
# Found 16 headers in 'A Video-Based End-to-end Pipeline for Non-nutritive Sucking Action Recognition and Segmentation in Young Infants'
# Found 19 headers in 'SFusion: Self-attention Based N-to-One Multimodal Fusion Block'
# Found 13 headers in 'VISA-FSS: A Volume-Informed Self Supervised Approach for Few-Shot 3D Segmentation'
# Found 15 headers in 'Gadolinium-Free Cardiac MRI Myocardial Scar Detection by 4D Convolution Factorization'
# Found 18 headers in 'ECL: Class-Enhancement Contrastive Learning for Long-Tailed Skin Lesion Classification'
# Found 12 headers in 'On the Relevance of Temporal Features for Medical Ultrasound Video Recognition'
# Found 18 headers in 'Multi-objective Point Cloud Autoencoders for Explainable Myocardial Infarction Prediction'
# Found 23 headers in 'FairAdaBN: Mitigating Unfairness with Adaptive Batch Normalization and Its Application to Dermatological Disease Classification'
# Found 13 headers in 'SLPT: Selective Labeling Meets Prompt Tuning on Label-Limited Lesion Segmentation'
# Found 13 headers in 'Self-aware and Cross-Sample Prototypical Learning for Semi-supervised Medical Image Segmentation'
# Creating a DataFrame with Extracted Data From'03MICCAI_notebook_GROBID_processed_volumes/vol3'...
# Found 11 headers in 'CheXstray: A Real-Time Multi-Modal Monitoring Workflow for Medical Imaging AI'
# Found 19 headers in 'CorSegRec: A Topology-Preserving Scheme for Extracting Fully-Connected Coronary Arteries from CT Angiography'
# Found 18 headers in 'Joint Dense-Point Representation for Contour-Aware Graph Segmentation'
# Found 15 headers in 'DiffMix: Diffusion Model-Based Data Synthesis for Nuclei Segmentation and Classification in Imbalanced Pathology Image Datasets'
# Found 21 headers in 'Fine-Tuning Network in Federated Learning for Personalized Skin Diagnosis'
# Found 13 headers in 'Fourier Test-Time Adaptation with Multi-level Consistency for Robust Classification'
# Found 14 headers in 'Performance Metrics for Probabilistic Ordinal Classifiers'
# Found 19 headers in 'UniSeg: A Prompt-Driven Universal Segmentation Model as Well as A Strong Representation Learner'
# Found 20 headers in 'Deep Learning-Based Anonymization of Chest Radiographs: A Utility-Preserving Measure for Patient Privacy'
# Found 17 headers in 'Cross-Modulated Few-Shot Image Generation for Colorectal Tissue Classification'
# Found 15 headers in 'Unpaired Cross-Modal Interaction Learning for COVID-19 Segmentation on Limited CT Images'
# Found 13 headers in 'The Role of Subgroup Separability in Group-Fair Medical Image Classification'
# Found 12 headers in 'Self-adaptive Adversarial Training for Robust Medical Segmentation'
# Found 21 headers in 'M3D-NCA: Robust 3D Segmentation with Built-In Quality Control'
# Found 18 headers in 'Structure-Preserving Instance Segmentation via Skeleton-Aware Distance Transform'
# Found 15 headers in 'Enhance Early Diagnosis Accuracy of Alzheimer’s Disease by Elucidating Interactions Between Amyloid Cascade and Tau Propagation'
# Found 13 headers in 'DAST: Differentiable Architecture Search with Transformer for 3D Medical Image Segmentation'
# Found 18 headers in 'Bidirectional Mapping with Contrastive Learning on Multimodal Neuroimaging Data'
# Found 19 headers in 'Mitigating Calibration Bias Without Fixed Attribute Grouping for Improved Fairness in Medical Imaging Analysis'
# Found 14 headers in 'Segmentation Distortion: Quantifying Segmentation Uncertainty Under Domain Shift via the Effects of Anomalous Activations'
# Found 13 headers in 'MultiTalent: A Multi-dataset Approach to Medical Image Segmentation'
# Found 18 headers in 'Boundary-Weighted Logit Consistency Improves Calibration of Segmentation Networks'
# Found 15 headers in 'Co-assistant Networks for Label Correction'
# Found 15 headers in 'Label-Preserving Data Augmentation in Latent Space for Diabetic Retinopathy Recognition'
# Found 22 headers in 'DRMC: A Generalist Model with Dynamic Routing for Multi-center PET Image Synthesis'
# Found 15 headers in 'Pre-trained Diffusion Models for Plug-and-Play Medical Image Enhancement'
# Found 16 headers in 'Robust T-Loss for Medical Image Segmentation'
# Found 13 headers in 'Multi-Head Multi-Loss Model Calibration'
# Found 22 headers in 'Scale Federated Learning for Label Set Mismatch in Medical Image Classification'
# Found 13 headers in '3D Medical Image Segmentation with Sparse Annotation via Cross-Teaching Between 3D and 2D Networks'
# Found 8 headers in 'Uncertainty and Shape-Aware Continual Test-Time Adaptation for Cross-Domain Segmentation of Medical Images'
# Found 18 headers in 'Guiding the Guidance: A Comparative Analysis of User Guidance Signals for Interactive Segmentation of Volumetric Images'
# Found 17 headers in 'Laplacian-Former: Overcoming the Limitations of Vision Transformers in Local Texture Detection'
# Found 11 headers in 'Towards Frugal Unsupervised Detection of Subtle Abnormalities in Medical Imaging'
# Found 13 headers in 'Understanding Silent Failures in Medical Image Classification'
# Found 16 headers in 'Evidence Reconciled Neural Network for Out-of-Distribution Detection in Medical Images'
# Found 21 headers in 'Scale-Aware Test-Time Click Adaptation for Pulmonary Nodule and Mass Segmentation'
# Found 16 headers in 'Chest X-ray Image Classification: A Causal Perspective'
# Found 14 headers in 'WeakPolyp: You only Look Bounding Box for Polyp Segmentation'
# Found 14 headers in 'DiMix: Disentangle-and-Mix Based Domain Generalizable Medical Image Segmentation'
# Found 14 headers in 'Deep Learning-Based Air Trapping Quantification Using Paired Inspiratory-Expiratory Ultra-low Dose CT'
# Found 11 headers in 'A Privacy-Preserving Walk in the Latent Space of Generative Models for Medical Applications'
# Found 18 headers in 'SwinMM: Masked Multi-view with Swin Transformers for 3D Medical Image Segmentation'
# Found 20 headers in 'Toward Fairness Through Fair Multi-Exit Framework for Dermatological Disease Diagnosis'
# Found 18 headers in 'SMRD: SURE-Based Robust MRI Reconstruction with Diffusion Models'
# Found 17 headers in 'Automatic Segmentation of Internal Tooth Structure from CBCT Images Using Hierarchical Deep Learning'
# Found 17 headers in 'Implicit Anatomical Rendering for Medical Image Segmentation with Stochastic Experts'
# Found 18 headers in 'Shifting More Attention to Breast Lesion Segmentation in Ultrasound Videos'
# Found 19 headers in 'ACC-UNet: A Completely Convolutional UNet Model for the 2020s'
# Found 17 headers in 'How Reliable are the Metrics Used for Assessing Reliability in Medical Imaging?'
# Found 15 headers in 'Uncovering Structural-Functional Coupling Alterations for Neurodegenerative Diseases'
# Found 18 headers in 'Data AUDIT: Identifying Attribute Utility-and Detectability-Induced Bias in Task Models'
# Found 14 headers in 'Assignment Theory-Augmented Neural Network for Dental Arch Labeling'
# Found 14 headers in 'FocalUNETR: A Focal Transformer for Boundary-Aware Prostate Segmentation Using CT Images'
# Found 16 headers in 'A Model-Agnostic Framework for Universal Anomaly Detection of Multi-organ and Multi-modal Images'
# Found 18 headers in 'Deep Mutual Distillation for Semi-supervised Medical Image Segmentation'
# Found 15 headers in 'Trust Your Neighbours: Penalty-Based Constraints for Model Calibration'
# Found 16 headers in 'Asymmetric Contour Uncertainty Estimation for Medical Image Segmentation'
# Found 17 headers in 'DHC: Dual-Debiased Heterogeneous Co-training Framework for Class-Imbalanced Semi-supervised Medical Image Segmentation'
# Found 15 headers in 'GRACE: A Generalized and Personalized Federated Learning Method for Medical Imaging'
# Found 14 headers in 'Deployment of Image Analysis Algorithms Under Prevalence Shifts'
# Found 9 headers in 'Enabling Geometry Aware Learning Through Differentiable Epipolar View Translation'
# Found 18 headers in 'Regular SE(3) Group Convolutions for Volumetric Medical Image Analysis'
# Found 13 headers in 'TauFlowNet: Uncovering Propagation Mechanism of Tau Aggregates by Neural Transport Equation'
# Found 17 headers in 'Federated Condition Generalization on Low-dose CT Reconstruction via Cross-domain Learning'
# Found 20 headers in 'Anatomical-Aware Point-Voxel Network for Couinaud Segmentation in Liver CT'
# Found 14 headers in 'HENet: Hierarchical Enhancement Network for Pulmonary Vessel Segmentation in Non-contrast CT Images'
# Found 20 headers in 'Dice Semimetric Losses: Optimizing the Dice Score with Soft Labels'
# Found 13 headers in 'Fully Bayesian VIB-DeepSSM'
# Found 13 headers in 'Maximum Entropy on Erroneous Predictions: Improving Model Calibration for Medical Image Segmentation'
# Found 17 headers in 'Temporal Uncertainty Localization to Enable Human-in-the-Loop Analysis of Dynamic Contrast-Enhanced Cardiac MRI Datasets'
# Found 21 headers in 'Minimal-Supervised Medical Image Segmentation via Vector Quantization Memory'
# Creating a DataFrame with Extracted Data From'03MICCAI_notebook_GROBID_processed_volumes/vol4'...
# Found 15 headers in 'Semi-supervised Domain Adaptive Medical Image Segmentation Through Consistency Regularized Disentangled Contrastive Learning'
# Found 18 headers in 'BerDiff: Conditional Bernoulli Diffusion Model for Medical Image Segmentation'
# Found 14 headers in 'Annotator Consensus Prediction for Medical Image Segmentation with Diffusion Models'
# Found 18 headers in 'Anti-adversarial Consistency Regularization for Data Augmentation: Applications to Robust Medical Image Segmentation'
# Found 16 headers in 'Multi-shot Prototype Contrastive Learning and Semantic Reasoning for Medical Image Segmentation'
# Found 15 headers in 'Collaborative Modality Generation and Tissue Segmentation for Early-Developing Macaque Brain MR Images'
# Found 16 headers in 'Few-Shot Medical Image Segmentation via a Region-Enhanced Prototypical Transformer'
# Found 12 headers in 'Multimodal CT and MR Segmentation of Head and Neck Organs-at-Risk'
# Found 15 headers in 'From Sparse to Precise: A Practical Editing Approach for Intracardiac Echocardiography Segmentation'
# Found 23 headers in 'Treasure in Distribution: A Domain Randomization Based Multi-source Domain Generalization for 2D Medical Image Segmentation'
# Found 21 headers in 'CAS-Net: Cross-View Aligned Segmentation by Graph Representation of Knees'
# Found 18 headers in 'Memory Replay for Continual Medical Image Segmentation Through Atypical Sample Selection'
# Found 14 headers in 'ConvFormer: Plug-and-Play CNN-Style Transformers for Improving Medical Image Segmentation'
# Found 11 headers in 'Self-supervised Learning via Inter-modal Reconstruction and Feature Projection Networks for Label-Efficient 3D-to-2D Segmentation'
# Found 16 headers in 'Fine-Grained Hand Bone Segmentation via Adaptive Multi-dimensional Convolutional Network and Anatomy-Constraint Loss'
# Found 20 headers in 'Diffusion Transformer U-Net for Medical Image Segmentation'
# Found 16 headers in 'ACTION++: Improving Semi-supervised Medical Image Segmentation with Adaptive Anatomical Contrast'
# Found 14 headers in 'Learning Reliability of Multi-modality Medical Images for Tumor Segmentation via Evidence-Identified Denoising Diffusion Probabilistic Models'
# Found 19 headers in 'Transformer-Based Annotation Bias-Aware Medical Image Segmentation'
# Found 17 headers in 'Breast Ultrasound Tumor Classification Using a Hybrid Multitask CNN-Transformer Network'
# Found 15 headers in 'DOMINO++: Domain-Aware Loss Regularization for Deep Learning Generalizability'
# Found 18 headers in 'SwinUNETR-V2: Stronger Swin Transformers with Stagewise Convolutions for 3D Medical Image Segmentation'
# Found 23 headers in 'Structure-Decoupled Adaptive Part Alignment Network for Domain Adaptive Mitochondria Segmentation'
# Found 16 headers in 'Devil is in Channels: Contrastive Single Domain Generalization for Medical Image Segmentation'
# Found 10 headers in 'Robust Segmentation via Topology Violation Detection and Feature Synthesis'
# Found 12 headers in 'SimPLe: Similarity-Aware Propagation Learning for Weakly-Supervised Breast Cancer Segmentation in DCE-MRI'
# Found 20 headers in 'Uncertainty-Informed Mutual Learning for Joint Medical Image Classification and Segmentation'
# Found 18 headers in 'Do We Really Need that Skip-Connection? Understanding Its Interplay with Task Complexity'
# Found 20 headers in 'One-Shot Traumatic Brain Segmentation with Adversarial Training and Uncertainty Rectification'
# Found 12 headers in 'Shape-Aware 3D Small Vessel Segmentation with Local Contrast Guided Attention'
# Found 12 headers in 'UPCoL: Uncertainty-Informed Prototype Consistency Learning for Semi-supervised Medical Image Segmentation'
# Found 16 headers in 'Conditional Diffusion Models for Weakly Supervised Medical Image Segmentation'
# Found 15 headers in 'DBTrans: A Dual-Branch Vision Transformer for Multi-Modal Brain Tumor Segmentation'
# Found 18 headers in 'HartleyMHA: Self-attention in Frequency Domain for Resolution-Robust and Parameter-Efficient 3D Image Segmentation'
# Found 12 headers in 'Ischemic Stroke Segmentation from a Cross-Domain Representation in Multimodal Diffusion Studies'
# Found 17 headers in 'MDViT: Multi-domain Vision Transformer for Small Medical Image Segmentation Datasets'
# Found 15 headers in 'Semi-supervised Class Imbalanced Deep Learning for Cardiac MRI Segmentation'
# Found 16 headers in 'RBGNet: Reliable Boundary-Guided Segmentation of Choroidal Neovascularization'
# Found 14 headers in 'Instructive Feature Enhancement for Dichotomous Medical Image Segmentation'
# Found 18 headers in 'M-GenSeg: Domain Adaptation for Target Modality Tumor Segmentation with Annotation-Efficient Supervision'
# Found 13 headers in 'Edge-Aware Multi-task Network for Integrating Quantification Segmentation and Uncertainty Prediction of Liver Tumor on Multi-modality Non-contrast MRI'
# Found 20 headers in 'RCS-YOLO: A Fast and High-Accuracy Object Detector for Brain Tumor Detection'
# Found 12 headers in 'Certification of Deep Learning Models for Medical Image Segmentation'
# Found 18 headers in 'Category-Level Regularized Unlabeled-to-Labeled Learning for Semi-supervised Prostate Segmentation with Multi-site Unlabeled Data'
# Found 16 headers in 'Ariadne’s Thread: Using Text Prompts to Improve Segmentation of Infected Areas from Chest X-ray Images'
# Found 22 headers in 'A Sheaf Theoretic Perspective for Robust Prostate Segmentation'
# Found 18 headers in 'MedNeXt: Transformer-Driven Scaling of ConvNets for Medical Image Segmentation'
# Found 16 headers in 'A General Stitching Solution for Whole-Brain 3D Nuclei Instance Segmentation from Microscopy Images'
# Found 17 headers in 'Deep Probability Contour Framework for Tumour Segmentation and Dose Painting in PET Images'
# Found 13 headers in 'NISF: Neural Implicit Segmentation Functions'
# Found 12 headers in 'A2FSeg: Adaptive Multi-modal Fusion Network for Medical Image Segmentation'
# Found 13 headers in 'Pre-operative Survival Prediction of Diffuse Glioma Patients with Joint Tumor Subtyping'
# Found 14 headers in 'Medical Boundary Diffusion Model for Skin Lesion Segmentation'
# Found 18 headers in 'H-DenseFormer: An Efficient Hybrid Densely Connected Transformer for Multimodal Tumor Segmentation'
# Found 13 headers in 'TransNuSeg: A Lightweight Multi-task Transformer for Nuclei Segmentation'
# Found 17 headers in 'Medical Image Computing and Computer Assisted Intervention – MICCAI 2023'
# Found 15 headers in 'Conditional Temporal Attention Networks for Neonatal Cortical Surface Reconstruction'
# Found 11 headers in 'QCResUNet: Joint Subject-Level and Voxel-Level Prediction of Segmentation Quality'
# Found 16 headers in 'Boundary Difference over Union Loss for Medical Image Segmentation'
# Found 15 headers in 'MI-SegNet: Mutual Information-Based US Segmentation for Unseen Domain Generalization'
# Found 11 headers in 'EGE-UNet: An Efficient Group Enhanced UNet for Skin Lesion Segmentation'
# Found 15 headers in 'Learning Ontology-Based Hierarchical Structural Relationship for Whole Brain Segmentation'
# Found 14 headers in 'Diffusion Kinetic Model for Breast Cancer Segmentation in Incomplete DCE-MRI'
# Found 13 headers in 'Class-Aware Feature Alignment for Domain Adaptative Mitochondria Segmentation'
# Found 17 headers in 'Morphology-Inspired Unsupervised Gland Segmentation via Selective Semantic Grouping'
# Found 14 headers in 'Consistency-Guided Meta-learning for Bootstrapping Semi-supervised Medical Image Segmentation'
# Found 14 headers in 'Elongated Physiological Structure Segmentation via Spatial and Scale Uncertainty-Aware Network'
# Found 20 headers in 'EchoGLAD: Hierarchical Graph Neural Networks for Left Ventricle Landmark Detection on Echocardiograms'
# Found 18 headers in 'GL-Fusion: Global-Local Fusion Network for Multi-view Echocardiogram Video Segmentation'
# Found 18 headers in 'EoFormer: Edge-Oriented Transformer for Brain Tumor Segmentation'
# Found 26 headers in 'EdgeMixup: Embarrassingly Simple Data Alteration to Improve Lyme Disease Lesion Segmentation and Diagnosis Fairness'
# Found 15 headers in 'Scaling up 3D Kernels with Bayesian Frequency Re-parameterization for Medical Image Segmentation'
# Found 12 headers in 'Evolutionary Normalization Optimization Boosts Semantic Segmentation Network Performance'
# Found 14 headers in 'Factor Space and Spectrum for Medical Hyperspectral Image Segmentation'
# Found 15 headers in 'Adult-Like Phase and Multi-scale Assistance for Isointense Infant Brain Tissue Segmentation'
# Creating a DataFrame with Extracted Data From'03MICCAI_notebook_GROBID_processed_volumes/vol5'...
# Found 11 headers in 'Graph-Theoretic Automatic Lesion Tracking and Detection of Patterns of Lesion Changes in Longitudinal CT Studies'
# Found 10 headers in 'Robust Exclusive Adaptive Sparse Feature Selection for Biomarker Discovery and Early Diagnosis of Neuropsychiatric Systemic Lupus Erythematosus'
# Found 17 headers in 'Multi-view Vertebra Localization and Identification from CT Images'
# Found 16 headers in 'CARL: Cross-Aligned Representation Learning for Multi-view Lung Cancer Histology Classification'
# Found 16 headers in 'Discovering Brain Network Dysfunction in Alzheimer’s Disease Using Brain Hypergraph Neural Network'
# Found 11 headers in 'Self- and Semi-supervised Learning for Gastroscopic Lesion Detection'
# Found 15 headers in 'Improving Image-Based Precision Medicine with Uncertainty-Aware Causal Models'
# Found 17 headers in 'SwIPE: Efficient and Robust Medical Image Segmentation with Implicit Patch Embeddings'
# Found 9 headers in 'Revisiting Feature Propagation and Aggregation in Polyp Segmentation'
# Found 10 headers in 'Identification of Disease-Sensitive Brain Imaging Phenotypes and Genetic Factors Using GWAS Summary Statistics'
# Found 15 headers in 'Adjustable Robust Transformer for High Myopia Screening in Optical Coherence Tomography'
# Found 10 headers in 'Towards Generalizable Diabetic Retinopathy Grading in Unseen Domains'
# Found 14 headers in 'Diversity-Preserving Chest Radiographs Generation from Reports in One Stage'
# Found 14 headers in 'Improved Flexibility and Interpretability of Large Vessel Stroke Prognostication Using Image Synthesis and Multi-task Learning'
# Found 14 headers in 'Unsupervised Classification of Congenital Inner Ear Malformations Using DeepDiffusion for Latent Space Representation'
# Found 8 headers in 'Joint Prediction of Response to Therapy, Molecular Traits, and Spatial Organisation in Colorectal Cancer Biopsies'
# Found 17 headers in 'Acute Ischemic Stroke Onset Time Classification with Dynamic Convolution and Perfusion Maps Fusion'
# Found 13 headers in 'You Don’t Have to Be Perfect to Be Amazing: Unveil the Utility of Synthetic Images'
# Found 12 headers in 'Beyond the Snapshot: Brain Tokenized Graph Transformer for Longitudinal Brain Functional Connectome Embedding'
# Found 17 headers in 'Automatic Bleeding Risk Rating System of Gastric Varices'
# Found 13 headers in 'Rad-ReStruct: A Novel VQA Benchmark and Method for Structured Radiology Reporting'
# Found 12 headers in 'Improving Outcome Prediction of Pulmonary Embolism by De-biased Multi-modality Model'
# Found 15 headers in 'Learning with Domain-Knowledge for Generalizable Prediction of Alzheimer’s Disease from Multi-site Structural MRI'
# Found 15 headers in 'Enhancing Breast Cancer Risk Prediction by Incorporating Prior Images'
# Found 16 headers in 'Multimodal Deep Fusion in Hyperbolic Space for Mild Cognitive Impairment Study'
# Found 12 headers in 'Contrastive Masked Image-Text Modeling for Medical Visual Representation Learning'
# Found 23 headers in 'Parse and Recall: Towards Accurate Lung Nodule Malignancy Prediction Like Radiologists'
# Found 16 headers in 'Uncertainty Inspired Autism Spectrum Disorder Screening'
# Found 15 headers in 'M&M: Tackling False Positives in Mammography with a Multi-view and Multi-instance Learning Sparse Detector'
# Found 12 headers in 'Reversing the Abnormal: Pseudo-Healthy Generative Networks for Anomaly Detection'
# Found 20 headers in 'DiffULD: Diffusive Universal Lesion Detection'
# Found 15 headers in 'SHISRCNet: Super-Resolution and Classification Network for Low-Resolution Breast Cancer Histopathology Image'
# Found 15 headers in 'Visual-Attribute Prompt Learning for Progressive Mild Cognitive Impairment Prediction'
# Found 13 headers in 'Text-Guided Foundation Model Adaptation for Pathological Image Classification'
# Found 14 headers in 'Distributionally Robust Image Classifiers for Stroke Diagnosis in Accelerated MRI'
# Found 18 headers in 'Contrastive Feature Decoupling for Weakly-Supervised Disease Detection'
# Found 15 headers in 'Dynamic Curriculum Learning via In-Domain Uncertainty for Medical Image Classification'
# Found 17 headers in 'Positive Definite Wasserstein Graph Kernel for Brain Disease Diagnosis'
# Found 19 headers in 'Multiple Prompt Fusion for Zero-Shot Lesion Detection Using Vision-Language Models'
# Found 17 headers in 'Fast Non-Markovian Diffusion Model for Weakly Supervised Anomaly Detection in Brain MR Images'
# Found 17 headers in 'Xplainer: From X-Ray Observations to Explainable Zero-Shot Diagnosis'
# Found 17 headers in 'Uncovering Heterogeneity in Alzheimer’s Disease from Graphical Modeling of the Tau Spatiotemporal Topography'
# Found 14 headers in 'MUVF-YOLOX: A Multi-modal Ultrasound Video Fusion Network for Renal Tumor Diagnosis'
# Found 20 headers in 'Visual Grounding of Whole Radiology Reports for 3D CT Images'
# Found 14 headers in 'Patients and Slides are Equal: A Multi-level Multi-instance Learning Framework for Pathological Image Analysis'
# Found 11 headers in 'Learning with Synthesized Data for Generalizable Lesion Detection in Real PET Images'
# Found 13 headers in 'What Do AEs Learn? Challenging Common Assumptions in Unsupervised Anomaly Detection'
# Found 14 headers in 'Utilizing Longitudinal Chest X-Rays and Reports to Pre-fill Radiology Reports'
# Found 14 headers in 'Transformer-Based Tooth Segmentation, Identification and Pulp Calcification Recognition in CBCT'
# Found 20 headers in 'How Does Pruning Impact Long-Tailed Multi-label Medical Image Classifiers?'
# Found 14 headers in 'Improved Prognostic Prediction of Pancreatic Cancer Using Multi-phase CT by Integrating Neural Distance and Texture-Aware Transformer'
# Found 19 headers in 'DCAug: Domain-Aware and Content-Consistent Cross-Cycle Framework for Tumor Augmentation'
# Found 18 headers in 'Hierarchical Vision Transformers for Disease Progression Detection in Chest X-Ray Images'
# Found 13 headers in 'Treatment Outcome Prediction for Intracerebral Hemorrhage via Generative Prognostic Model with Imaging and Tabular Data'
# Found 19 headers in 'Smooth Attention for Deep Multiple Instance Learning: Application to CT Intracranial Hemorrhage Detection'
# Found 17 headers in 'Open-Ended Medical Visual Question Answering Through Prefix Tuning of Language Models'
# Found 13 headers in 'Personalized Patch-Based Normality Assessment of Brain Atrophy in Alzheimer’s Disease'
# Found 20 headers in 'COVID-19 Pneumonia Classification with Transformer from Incomplete Modalities'
# Found 14 headers in 'Flexible Unfolding of Circular Structures for Rendering Textbook-Style Cerebrovascular Maps'
# Found 17 headers in 'Cluster-Induced Mask Transformers for Effective Opportunistic Gastric Cancer Screening on Non-contrast CT Scans'
# Found 15 headers in 'Self-supervised Polyp Re-identification in Colonoscopy'
# Found 14 headers in 'Punctate White Matter Lesion Segmentation in Preterm Infants Powered by Counterfactually Generative Learning'
# Found 14 headers in 'Privacy-Preserving Early Detection of Epileptic Seizures in Videos'
# Found 13 headers in 'YONA: You Only Need One Adjacent Reference-Frame for Accurate and Fast Video Polyp Detection'
# Found 16 headers in 'Boosting Breast Ultrasound Video Classification by the Guidance of Keyframe Feature Centers'
# Found 15 headers in 'Text-Guided Cross-Position Attention for Segmentation: Case of Medical Image'
# Found 17 headers in 'Detecting Domain Shift in Multiple Instance Learning for Digital Pathology Using Fréchet Domain Distance'
# Found 14 headers in 'Style-Based Manifold for Weakly-Supervised Disease Characteristic Discovery'
# Found 13 headers in 'Liver Tumor Screening and Diagnosis in CT with Pixel-Lesion-Patient Network'
# Found 22 headers in 'Recruiting the Best Teacher Modality: A Customized Knowledge Distillation Method for if Based Nephropathy Diagnosis'
# Found 12 headers in 'A Multimodal Disease Progression Model for Genetic Associations with Disease Dynamics'
# Found 14 headers in 'Self-supervised Learning for Endoscopic Video Analysis'
# Found 18 headers in 'GSDG: Exploring a Global Semantic-Guided Dual-Stream Graph Model for Automated Volume Differential Diagnosis and Prognosis'
# Found 17 headers in 'Convolving Directed Graph Edges via Hodge Laplacian for Brain Network Analysis'
# Found 15 headers in 'cOOpD: Reformulating COPD Classification on Chest CT Scans as Anomaly Detection Using Contrastive Representations'
# Found 19 headers in 'A Reliable and Interpretable Framework of Multi-view Learning for Liver Fibrosis Staging'
# Creating a DataFrame with Extracted Data From'03MICCAI_notebook_GROBID_processed_volumes/vol6'...
# Found 18 headers in 'Merging-Diverging Hybrid Transformer Networks for Survival Prediction in Head and Neck Cancer'
# Found 16 headers in 'Wall Thickness Estimation from Short Axis Ultrasound Images via Temporal Compatible Deformation Learning'
# Found 14 headers in 'DiffMIC: Dual-Guidance Diffusion Network for Medical Image Classification'
# Found 16 headers in 'Polar Eyeball Shape Net for 3D Posterior Ocular Shape Representation'
# Found 17 headers in 'ALL-IN: A Local GLobal Graph-Based DIstillatioN Model for Representation Learning of Gigapixel Histopathology Images With Application In Cancer Risk Assessment'
# Found 12 headers in 'A One-Class Variational Autoencoder (OCVAE) Cascade for Classifying Atypical Bone Marrow Cell Sub-types'
# Found 14 headers in 'SegNetr: Rethinking the Local-Global Interactions and Skip Connections in U-Shaped Networks'
# Found 21 headers in 'DARC: Distribution-Aware Re-Coloring Model for Generalizable Nucleus Segmentation'
# Found 20 headers in 'An AI-Ready Multiplex Staining Dataset for Reproducible and Accurate Characterization of Tumor Immune Microenvironment'
# Found 21 headers in 'Detection of Basal Cell Carcinoma in Whole Slide Images'
# Found 19 headers in 'IIB-MIL: Integrated Instance-Level and Bag-Level Multiple Instances Learning with Label Disambiguation for Pathological Image Analysis'
# Found 17 headers in 'Multi-scale Prototypical Transformer for Whole Slide Image Classification'
# Found 19 headers in 'SCOL: Supervised Contrastive Ordinal Loss for Abdominal Aortic Calcification Scoring on Vertebral Fracture Assessment Scans'
# Found 15 headers in 'Thyroid Nodule Diagnosis in Dynamic Contrast-Enhanced Ultrasound via Microvessel Infiltration Awareness'
# Found 17 headers in 'Mitral Regurgitation Quantification from Multi-channel Ultrasound Images via Deep Learning'
# Found 17 headers in 'Label-Free Nuclei Segmentation Using Intra-Image Self Similarity'
# Found 20 headers in 'Triangular Analysis of Geographical Interplay of Lymphocytes (TriAnGIL): Predicting Immunotherapy Response in Lung Cancer'
# Found 19 headers in 'NASDM: Nuclei-Aware Semantic Histopathology Image Generation Using Diffusion Models'
# Found 16 headers in 'DiffDP: Radiotherapy Dose Prediction via a Diffusion Model'
# Found 16 headers in 'Coupling Bracket Segmentation and Tooth Surface Reconstruction on 3D Dental Models'
# Found 11 headers in 'Whole-Heart Reconstruction with Explicit Topology Integrated Learning'
# Found 20 headers in 'Position-Aware Masked Autoencoder for Histopathology WSI Representation Learning'
# Found 13 headers in 'Detection-Free Pipeline for Cervical Cancer Screening of Whole Slide Images'
# Found 20 headers in 'Democratizing Pathological Image Segmentation with Lay Annotators via Molecular-Empowered Learning'
# Found 14 headers in 'Diffusion-Based Hierarchical Multi-label Object Detection to Analyze Panoramic Dental X-Rays'
# Found 15 headers in 'MulHiST: Multiple Histological Staining for Thick Biological Samples via Unsupervised Image-to-Image Translation'
# Found 17 headers in 'Instance-Aware Diffusion Model for Gland Segmentation in Colon Histology Images'
# Found 15 headers in 'Adaptive Supervised PatchNCE Loss for Learning H&E-to-IHC Stain Translation with Inconsistent Groundtruth Image Pairs'
# Found 14 headers in 'Gradient and Feature Conformity-Steered Medical Image Classification with Noisy Labels'
# Found 14 headers in 'Medical Image Computing and Computer Assisted Intervention – MICCAI 2023'
# Found 13 headers in 'Forensic Histopathological Recognition via a Context-Aware MIL Network Powered by Self-supervised Contrastive Learning'
# Found 15 headers in 'ProtoASNet: Dynamic Prototypes for Inherently Interpretable and Uncertainty-Aware Aortic Stenosis Classification in Echocardiography'
# Found 15 headers in 'HIGT: Hierarchical Interaction Graph-Transformer for Whole Slide Image Analysis'
# Found 19 headers in 'Learning Robust Classifier for Imbalanced Medical Image Dataset with Noisy Labels by Minimizing Invariant Risk'
# Found 17 headers in 'MPBD-LSTM: A Predictive Model for Colorectal Liver Metastases Using Time Series Multi-phase Contrast-Enhanced CT Scans'
# Found 17 headers in 'Deep Cellular Embeddings: An Explainable Plug and Play Improvement for Feature Representation in Histopathology'
# Found 16 headers in 'HC-Net: Hybrid Classification Network for Automatic Periodontal Disease Diagnosis'
# Found 19 headers in 'Anatomical Landmark Detection Using a Multiresolution Learning Approach with a Hybrid Transformer-CNN Model'
# Found 11 headers in 'Transformer-Based End-to-End Classification of Variable-Length Volumetric Data'
# Found 14 headers in 'Progressive Attention Guidance for Whole Slide Vulvovaginal Candidiasis Screening'
# Found 12 headers in 'Frequency-Mixed Single-Source Domain Generalization for Medical Image Segmentation'
# Found 19 headers in 'Vision Transformer Based Multi-class Lesion Detection in IVOCT'
# Found 14 headers in 'CellGAN: Conditional Cervical Cell Synthesis for Augmenting Cytopathological Image Classification'
# Found 11 headers in 'An Anti-biased TBSRTC-Category Aware Nuclei Segmentation Framework with a Multi-label Thyroid Cytology Benchmark'
# Found 16 headers in 'Zero-Shot Nuclei Detection via Visual-Language Pre-trained Models'
# Found 14 headers in 'Medical Image Computing and Computer Assisted Intervention – MICCAI 2023'
# Found 19 headers in 'A Semantic-Guided and Knowledge-Based Generative Framework for Orthodontic Visual Outcome Preview'
# Found 17 headers in 'Joint Segmentation and Sub-pixel Localization in Structured Light Laryngoscopy'
# Found 16 headers in 'Multi-modal Pathological Pre-training via Masked Autoencoders for Breast Cancer Diagnosis'
# Found 17 headers in 'Accurate and Robust Patient Height and Weight Estimation in Clinical Imaging Using a Depth Camera'
# Found 23 headers in 'Segment Membranes and Nuclei from Histopathological Images via Nuclei Point-Level Supervision'
# Found 16 headers in 'Cross-View Deformable Transformer for Non-displaced Hip Fracture Classification from Frontal-Lateral X-Ray Pair'
# Found 12 headers in 'Semi-supervised Pathological Image Segmentation via Cross Distillation of Multiple Attentions'
# Found 9 headers in 'Towards Novel Class Discovery: A Study in Novel Skin Lesions Clustering'
# Found 20 headers in 'Enhancing Automatic Placenta Analysis Through Distributional Feature Recomposition in Vision-Language Contrastive Learning'
# Found 17 headers in 'Interpretable Deep Biomarker for Serial Monitoring of Carotid Atherosclerosis Based on Three-Dimensional Ultrasound Imaging'
# Found 9 headers in 'Pathology-and-Genomics Multimodal Transformer for Survival Outcome Prediction'
# Found 15 headers in 'Improving Pathology Localization: Multi-series Joint Attention Takes the Lead'
# ...
# Found 16 headers in 'EndoSurf: Neural Surface Reconstruction of Deformable Tissues with Stereo Endoscope Videos'
# Found 11 headers in 'Intra-operative Forecasting of Standing Spine Shape with Articulated Neural Kernel Fields'
# Found 13 headers in 'ConTrack: Contextual Transformer for Device Tracking in X-Ray'
# Found 10 headers in 'Ultrasonic Tracking of a Rapid-Exchange Microcatheter with Simultaneous Pressure Sensing for Cardiovascular Interventions'
# Found 16 headers in 'Spatiotemporal Incremental Mechanics Modeling of Facial Tissue Change'
# Found 16 headers in 'A Multi-task Network for Anatomy Identification in Endoscopic Pituitary Surgery'
# Found 18 headers in 'Intraoperative CT Augmentation for Needle-Based Liver Interventions'
# Found 13 headers in 'Optical Coherence Elastography Needle for Biomechanical Characterization of Deep Tissue'
# Found 14 headers in 'POV-Surgery: A Dataset for Egocentric Hand and Tool Pose Estimation During Surgical Activities'
# Found 17 headers in 'Semantic Virtual Shadows (SVS) for Improved Perception in 4D OCT Guided Surgery'
# Found 20 headers in 'Spinal Nerve Segmentation Method and Dataset Construction in Endoscopic Surgical Scenarios'
# Found 12 headers in 'Optical Ultrasound Imaging for Endovascular Repair of Abdominal Aortic Aneurysms: A Pilot Study'
# Found 19 headers in 'Synthesising Rare Cataract Surgery Samples with Guided Diffusion Models'
# Found 16 headers in 'Multi-task Joint Prediction of Infant Cortical Morphological and Cognitive Development'
# Found 14 headers in 'Self-distillation for Surgical Action Recognition'
# Found 14 headers in 'Automatic Surgical Reconstruction for Orbital Blow-Out Fracture via Symmetric Prior Anatomical Knowledge-Guided Adversarial Generative Network'
# Found 14 headers in 'Robust Vertebra Identification Using Simultaneous Node and Edge Predicting Graph Neural Networks'
# Found 14 headers in 'Pelvic Fracture Segmentation Using a Multi-scale Distance-Weighted Neural Network'
# Found 20 headers in 'Analysis of Suture Force Simulations for Optimal Orientation of Rhomboid Skin Flaps'
# Found 7 headers in 'A Transfer Learning Approach to Localising a Deep Brain Stimulation Target'
# Found 18 headers in 'Towards Multi-modal Anatomical Landmark Detection for Ultrasound-Guided Brain Tumor Resection with Contrastive Learning'
# Found 13 headers in 'SegmentOR: Obtaining Efficient Operating Room Semantics Through Temporal Propagation'
# Found 11 headers in 'SENDD: Sparse Efficient Neural Depth and Deformation for Tissue Tracking'
# Found 16 headers in 'Deep Reinforcement Learning Based System for Intraoperative Hyperspectral Video Autofocusing'
# Found 18 headers in 'Surgical Video Captioning with Mutual-Modal Concept Alignment'
# Found 24 headers in 'SurgicalGPT: End-to-End Language-Vision GPT for Visual Question Answering in Surgery'
# Found 13 headers in 'A Unified Deep-Learning-Based Framework for Cochlear Implant Electrode Array Localization'
# Found 14 headers in 'LABRAD-OR: Lightweight Memory Scene Graphs for Accurate Bimodal Reasoning in Dynamic Operating Rooms'
# Found 15 headers in 'Realistic Endoscopic Illumination Modeling for NeRF-Based Data Generation'
# Found 14 headers in 'High-Resolution Cranial Defect Reconstruction by Iterative, Low-Resolution, Point Cloud Completion Transformers'
# Found 19 headers in 'Foundation Model for Endoscopy Video Analysis via Large-Scale Self-supervised Pre-train'
# Found 14 headers in 'Imitation Learning from Expert Video Data for Dissection Trajectory Prediction in Endoscopic Surgical Procedure'
# Found 16 headers in 'Cochlear Implant Fold Detection in Intra-operative CT Using Weakly Supervised Multi-task Deep Learning'
# Found 18 headers in 'Multi-view Guidance for Self-supervised Monocular Depth Estimation on Laparoscopic Images via Spatio-Temporal Correspondence'
# Found 12 headers in 'From Tissue to Sound: Model-Based Sonification of Medical Imaging'
# Found 15 headers in 'Self-supervised Sim-to-Real Kinematics Reconstruction for Video-Based Assessment of Intraoperative Suturing Skills'
# Found 14 headers in 'Regularized Kelvinlet Functions to Model Linear Elasticity for Image-to-Physical Registration of the Breast'
# Found 15 headers in 'Estimated Time to Surgical Procedure Completion: An Exploration of Video Analysis Methods'
# Found 14 headers in 'Medical Image Computing and Computer Assisted Intervention – MICCAI 2023'
# Found 17 headers in 'Learnable Query Initialization for Surgical Instrument Instance Segmentation'
# Found 18 headers in 'Learning Expected Appearances for Intraoperative Registration During Neurosurgery'
# Found 16 headers in 'Dose Guidance for Radiotherapy-Oriented Deep Learning Segmentation'
# Found 15 headers in 'FLIm-Based in Vivo Classification of Residual Cancer in the Surgical Cavity During Transoral Robotic Surgery'
# Found 17 headers in 'Regressing Simulation to Real: Unsupervised Domain Adaptation for Automated Quality Assessment in Transoesophageal Echocardiography'
# Found 19 headers in 'Revisiting Distillation for Continual Learning on Visual Question Localized-Answering in Robotic Surgery'
# Found 16 headers in 'Encoding Surgical Videos as Latent Spatiotemporal Graphs for Object and Anatomy-Driven Reasoning'
# Found 14 headers in 'Pelvic Fracture Reduction Planning Based on Morphable Models and Structural Constraints'
# Found 18 headers in 'FocalErrorNet: Uncertainty-Aware Focal Modulation Network for Inter-modal Registration Error Estimation in Ultrasound-Guided Neurosurgery'
# Found 10 headers in '$$\textsf{GLSFormer}$$: Gated - Long, Short Sequence Transformer for Step Recognition in Surgical Videos'
# Found 15 headers in 'Soft-Tissue Driven Craniomaxillofacial Surgical Planning'
# Found 19 headers in 'A Closed-Form Solution to Electromagnetic Sensor Based Intraoperative Limb Length Measurement in Total Hip Arthroplasty'
# Found 17 headers in 'Detecting the Sensing Area of a Laparoscopic Probe in Minimally Invasive Cancer Surgery'
# Found 16 headers in 'From Mesh Completion to AI Designed Crown'
# Found 16 headers in 'SEDSkill: Surgical Events Driven Method for Skill Assessment from Thoracoscopic Surgical Videos'
# Found 13 headers in 'Point Cloud Diffusion Models for Automatic Implant Generation'
# Found 20 headers in 'Surgical Action Triplet Detection by Mixed Supervised Learning of Instrument-Tissue Interactions'
# Found 16 headers in 'High-Quality Virtual Single-Viewpoint Surgical Video: Geometric Autocalibration of Multiple Cameras in Surgical Lights'
# Found 17 headers in 'CAT-ViL: Co-attention Gated Vision-Language Embedding for Visual Question Localized-Answering in Robotic Surgery'
# Found 18 headers in 'Rectifying Noisy Labels with Sequential Prior: Multi-scale Temporal Feature Affinity Learning for Robust Video Segmentation'
# Found 21 headers in 'Neural LerPlane Representations for Fast 4D Reconstruction of Deformable Tissues'
# Found 14 headers in 'ACT-Net: Anchor-Context Action Detection in Surgery Videos'
# Found 14 headers in 'Intelligent Virtual B-Scan Mirror (IVBM)'
# Found 17 headers in 'Surgical Activity Triplet Recognition via Triplet Disentanglement'
# Found 16 headers in 'A Novel Video-CTU Registration Method with Structural Point Similarity for FURS Navigation'
# Found 17 headers in 'UXDiff: Synthesis of X-Ray Image from Ultrasound Coronal Image of Spine with Diffusion Probabilistic Network'
# Found 13 headers in 'Semantic Segmentation of Surgical Hyperspectral Images Under Geometric Domain Shifts'
# Found 15 headers in 'TCL: Triplet Consistent Learning for Odometry Estimation of Monocular Endoscope'
# Found 15 headers in 'Cascade Transformer Encoded Boundary-Aware Multibranch Fusion Networks for Real-Time and Accurate Colonoscopic Lesion Segmentation'
# Found 21 headers in 'Deep Homography Prediction for Endoscopic Camera Motion Imitation Learning'
# Found 16 headers in 'A Patient-Specific Self-supervised Model for Automatic X-Ray/CT Registration'
# Creating a DataFrame with Extracted Data From'03MICCAI_notebook_GROBID_processed_volumes/vol10'...
# Found 15 headers in 'Noise Conditioned Weight Modulation for Robust and Generalizable Low Dose CT Denoising'
# Found 14 headers in 'CDiffMR: Can We Replace the Gaussian Noise with K-Space Undersampling for Fast MRI?'
# Found 15 headers in 'ModeT: Learning Deformable Image Registration via Motion Decomposition Transformer'
# Found 15 headers in 'CT Kernel Conversion Using Multi-domain Image-to-Image Translation with Generator-Guided Contrastive Learning'
# Found 18 headers in '$$\mathrm {H^{2}}$$GM: A Hierarchical Hypergraph Matching Framework for Brain Landmark Alignment'
# Found 12 headers in 'A Denoised Mean Teacher for Domain Adaptive Point Cloud Registration'
# Found 15 headers in 'PIViT: Large Deformation Image Registration with Pyramid-Iterative Vision Transformer'
# Found 15 headers in 'Unified Brain MR-Ultrasound Synthesis Using Multi-modal Hierarchical Representations'
# Found 23 headers in 'SAMConvex: Fast Discrete Optimization for CT Registration Using Self-supervised Anatomical Embedding and Correlation Pyramid'
# Found 10 headers in 'Feature-Conditioned Cascaded Video Diffusion Models for Precise Echocardiogram Synthesis'
# Found 19 headers in 'Implicit Neural Representations for Joint Decomposition and Registration of Gene Expression Images in the Marmoset Brain'
# Found 12 headers in 'DiffuseIR: Diffusion Models for Isotropic Reconstruction of 3D Microscopic Images'
# Found 21 headers in 'Building a Bridge: Close the Domain Gap in CT Metal Artifact Reduction'
# Found 16 headers in 'StructuRegNet: Structure-Guided Multimodal 2D-3D Registration'
# Found 14 headers in 'X2Vision: 3D CT Reconstruction from Biplanar X-Rays with Deep Structure Prior'
# Found 16 headers in 'RESToring Clarity: Unpaired Retina Image Enhancement Using Scattering Transform'
# Found 18 headers in 'Structure-Preserving Synthesis: MaskGAN for Unpaired MR-CT Translation'
# Found 18 headers in 'Learned Alternating Minimization Algorithm for Dual-Domain Sparse-View CT Reconstruction'
# Found 19 headers in 'TriDo-Former: A Triple-Domain Transformer for Direct PET Reconstruction from Low-Dose Sinograms'
# Found 15 headers in 'MoCoSR: Respiratory Motion Correction and Super-Resolution for 3D Abdominal MRI'
# Found 16 headers in 'MRIS: A Multi-modal Retrieval Approach for Image Synthesis on Diverse Modalities'
# Found 20 headers in 'FreeSeed: Frequency-Band-Aware and Self-guided Network for Sparse-View CT Reconstruction'
# Found 22 headers in 'ASCON: Anatomy-Aware Supervised Contrastive Learning Framework for Low-Dose CT Denoising'
# Found 12 headers in 'Co-learning Semantic-Aware Unsupervised Segmentation for Pathological Image Registration'
# Found 16 headers in 'Importance Weighted Variational Cardiac MRI Registration Using Transformer and Implicit Prior'
# Found 15 headers in 'Unsupervised 3D Registration Through Optimization-Guided Cyclical Self-training'
# Found 14 headers in 'Make-A-Volume: Leveraging Latent Diffusion Models for Cross-Modality 3D Brain MRI Synthesis'
# Found 12 headers in 'Fast Reconstruction for Deep Learning PET Head Motion Correction'
# Found 14 headers in 'Contrastive Diffusion Model with Auxiliary Guidance for Coarse-to-Fine PET Reconstruction'
# Found 14 headers in 'Dual Domain Motion Artifacts Correction for MR Imaging Under Guidance of K-space Uncertainty'
# Found 15 headers in 'GSMorph: Gradient Surgery for Cine-MRI Cardiac Deformable Registration'
# Found 14 headers in 'Motion Compensated Unsupervised Deep Learning for 5D MRI'
# Found 18 headers in 'An Unsupervised Multispectral Image Registration Network for Skin Diseases'
# Found 17 headers in 'Generating High-Resolution 3D CT with 12-Bit Depth Using a Diffusion Model with Adjacent Slice and Intensity Calibration Network'
# Found 10 headers in 'Revealing Anatomical Structures in PET to Generate CT for Attenuation Correction'
# Found 19 headers in 'Learning Deep Intensity Field for Extremely Sparse-View CBCT Reconstruction'
# Found 15 headers in 'Dual Arbitrary Scale Super-Resolution for Multi-contrast MRI'
# Found 12 headers in 'CortexMorph: Fast Cortical Thickness Estimation via Diffeomorphic Registration Using VoxelMorph'
# Found 16 headers in 'Physics-Informed Neural Networks for Tissue Elasticity Reconstruction in Magnetic Resonance Elastography'
# Found 19 headers in 'CycleSTTN: A Learning-Based Temporal Model for Specular Augmentation in Endoscopy'
# Found 17 headers in 'An Explainable Deep Framework: Towards Task-Specific Fusion for Multi-to-One MRI Synthesis'
# Found 13 headers in 'Inverse Consistency by Construction for Multistep Deep Registration'
# Found 13 headers in 'Geometric Ultrasound Localization Microscopy'
# Found 16 headers in 'Transformer-Based Dual-Domain Network for Few-View Dedicated Cardiac SPECT Image Reconstructions'
# Found 19 headers in 'JCCS-PFGM: A Novel Circle-Supervision Based Poisson Flow Generative Model for Multiphase CECT Progressive Low-Dose Reconstruction with Joint Condition'
# Found 14 headers in 'MEPNet: A Model-Driven Equivariant Proximal Network for Joint Sparse-View Reconstruction and Metal Artifact Reduction in CT Images'
# Found 18 headers in 'Estimation of 3T MR Images from 1.5T Images Regularized with Physics Based Constraint'
# Found 13 headers in 'Accurate Multi-contrast MRI Super-Resolution via a Dual Cross-Attention Transformer Network'
# Found 14 headers in 'Reflectance Mode Fluorescence Optical Tomography with Consumer-Grade Cameras'
# Found 15 headers in 'Computationally Efficient 3D MRI Reconstruction with Adaptive MLP'
# Found 15 headers in 'DISA: DIfferentiable Similarity Approximation for Universal Multimodal Registration'
# Found 16 headers in 'Differentiable Beamforming for Ultrasound Autofocusing'
# Found 13 headers in '3D Teeth Reconstruction from Panoramic Radiographs Using Neural Implicit Functions'
# Found 16 headers in 'Progressively Coupling Network for Brain MRI Registration in Few-Shot Situation'
# Found 16 headers in 'S3M: Scalable Statistical Shape Modeling Through Unsupervised Correspondences'
# Found 20 headers in 'Self-supervised MRI Reconstruction with Unrolled Diffusion Models'
# Found 15 headers in 'FSDiffReg: Feature-Wise and Score-Wise Diffusion-Guided Unsupervised Deformable Image Registration for Cardiac Images'
# Found 13 headers in 'Solving Low-Dose CT Reconstruction via GAN with Local Coherence'
# Found 12 headers in 'Multi-perspective Adaptive Iteration Network for Metal Artifact Reduction'
# Found 11 headers in 'Noise2Aliasing: Unsupervised Deep Learning for View Aliasing and Noise Reduction in 4DCBCT'
# Found 17 headers in 'DULDA: Dual-Domain Unsupervised Learned Descent Algorithm for PET Image Reconstruction'
# Found 14 headers in 'Low-Dose CT Image Super-Resolution Network with Dual-Guidance Feature Distillation and Dual-Path Content Communication'
# Found 16 headers in 'Non-iterative Coarse-to-Fine Transformer Networks for Joint Affine and Deformable Image Registration'
# Found 16 headers in 'X-Ray to CT Rigid Registration Using Scene Coordinate Regression'
# Found 16 headers in 'Trackerless Volume Reconstruction from Intraoperative Ultrasound Images'
# Found 12 headers in 'DisC-Diff: Disentangled Conditional Diffusion Model for Multi-contrast MRI Super-Resolution'
# Found 15 headers in 'CoLa-Diff: Conditional Latent Diffusion Model for Multi-modal MRI Synthesis'
# Found 15 headers in 'InverseSR: 3D Brain MRI Super-Resolution Using a Latent Diffusion Model'
# Found 18 headers in 'LLCaps: Learning to Illuminate Low-Light Capsule Endoscopy with Curved Wavelet Attention and Reverse Diffusion'
# Found 14 headers in 'Global k-Space Interpolation for Dynamic MRI Reconstruction Using Masked Image Modeling'
# Found 17 headers in 'Nonuniformly Spaced Control Points Based on Variational Cardiac Image Registration'
# Found 16 headers in 'Alias-Free Co-modulated Network for Cross-Modality Synthesis and Super-Resolution of MR Images'
# Found 16 headers in 'Topology-Preserving Computed Tomography Super-Resolution Based on Dual-Stream Diffusion Model'
# Found 13 headers in 'LightNeuS: Neural Surface Reconstruction in Endoscopy Using Illumination Decline'

# %% [markdown]
# ### Processing dataframes for all 10 volumes within a dictionary
# ***
# - Cleaning rows by removing non-relevant rows

# %%
def process_xml_folder(folder_path):
    df = pd.read_csv(folder_path)
    return df

def clean_dataframe(df):
    # Remove rows where both 'Header Title' and 'Text' are NaN or just 'Text' is NaN
    df_cleaned = df.dropna(subset=['Header Title', 'Text'], how='all')
    df_cleaned = df_cleaned.dropna(subset=['Text'], how='any')
    return df_cleaned

# Dictionary to store cleaned DataFrames
cleaned_dataframes = {}

# Base path where all processed volumes are stored
base_path = '03MICCAI_notebook_GROBID_dataframes'


output_folder = '03MICCAI_notebook_cleaned_dataframes'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

#/03MICCAI_notebook_GROBID_dataframes/03MICCAI_notebook_df_vol1_headers.csv
# Cleaning the DataFrames created from the XML files for each volume
for volume_number in range(1, 11):
    folder_path = f'{base_path}/03MICCAI_notebook_df_vol{volume_number}_headers.csv'
    print(f"Cleaning DataFrame for '{folder_path}'...")
    # Process the XML files in the folder and create a DataFrame
    df_headers = process_xml_folder(folder_path)
    # Clean the DataFrame
    df_cleaned = clean_dataframe(df_headers)
    # Save the cleaned DataFrame to a CSV file in the output folder
    df_cleaned.to_csv(f"03MICCAI_notebook_cleaned_dataframes/03MICCAI_notebook_df_vol{volume_number}_cleaned.csv", index=False)
# Out:
# Cleaning DataFrame for '03MICCAI_notebook_GROBID_dataframes_2/03MICCAI_notebook_df_vol1_headers.csv'...
# Cleaning DataFrame for '03MICCAI_notebook_GROBID_dataframes_2/03MICCAI_notebook_df_vol2_headers.csv'...
# Cleaning DataFrame for '03MICCAI_notebook_GROBID_dataframes_2/03MICCAI_notebook_df_vol3_headers.csv'...
# Cleaning DataFrame for '03MICCAI_notebook_GROBID_dataframes_2/03MICCAI_notebook_df_vol4_headers.csv'...
# Cleaning DataFrame for '03MICCAI_notebook_GROBID_dataframes_2/03MICCAI_notebook_df_vol5_headers.csv'...
# Cleaning DataFrame for '03MICCAI_notebook_GROBID_dataframes_2/03MICCAI_notebook_df_vol6_headers.csv'...
# Cleaning DataFrame for '03MICCAI_notebook_GROBID_dataframes_2/03MICCAI_notebook_df_vol7_headers.csv'...
# Cleaning DataFrame for '03MICCAI_notebook_GROBID_dataframes_2/03MICCAI_notebook_df_vol8_headers.csv'...
# Cleaning DataFrame for '03MICCAI_notebook_GROBID_dataframes_2/03MICCAI_notebook_df_vol9_headers.csv'...
# Cleaning DataFrame for '03MICCAI_notebook_GROBID_dataframes_2/03MICCAI_notebook_df_vol10_headers.csv'...

# %%
# Check the number of unique paper titles in the cleaned DataFrames for volume 10
len(df_cleaned['Paper Title'].unique())

# %% [markdown]
# #### Checking to see if papers per volume are missing after cleaning the dataframes
# ***

# %%
# Read in the folder with the cleaned_dataframes
folder_path = '03MICCAI_notebook_cleaned_dataframes'

# Verify unique title counts in the individual and saved dataframes before combining
total_unique = 0
for volume_number in range(1, 11):
    file_path = f'{folder_path}/03MICCAI_notebook_df_vol{volume_number}_cleaned.csv'
    df = pd.read_csv(file_path)
    unique_in_df = len(df['Paper Title'].unique())
    print(f"Unique titles in vol{volume_number}: {unique_in_df}")
    total_unique += unique_in_df

print(f"Sum of unique titles from individual DataFrames: {total_unique}") 
# 2 unique titles missing, 1 in vol6 and vol7 each:
# vol6: A Multi-task Method for Immunofixation Electrophoresis Image Classification (paper_15)
# vol7: DMCVR: Morphology-Guided Diffusion Model for 3D Cardiac Volume Reconstruction

# 2 titles are named "Medical_Image_Computing_and_Computer_Assisted_Intervention_–_MICCAI_2023" in the dataframes
# vol6: AR2T:_Adaptive_Robust_Regression_Tree_for_Medical_Image_Segmentation
# vol7: Virtual Heart Models Help Elucidate the Role of Border Zone in Sustained Monomorphic Ventricular Tachycardia
# rename the files in the folder and re-run the code block
# Out:
# Unique titles in vol1: 73
# Unique titles in vol2: 73
# Unique titles in vol3: 72
# Unique titles in vol4: 75
# Unique titles in vol5: 76
# Unique titles in vol6: 77
# Unique titles in vol7: 75
# Unique titles in vol8: 65
# Unique titles in vol9: 70
# Unique titles in vol10: 74
# Sum of unique titles from individual DataFrames: 730

# %%
# Merge all cleaned DataFrames into a single DataFrame
all_cleaned_dataframes = []
for volume_number in range(1, 11):
    file_path = f'{folder_path}/03MICCAI_notebook_df_vol{volume_number}_cleaned.csv'
    df = pd.read_csv(file_path)
    all_cleaned_dataframes.append(df)

# Convert the list of DataFrames into a single DataFrame
df_all_cleaned = pd.concat(all_cleaned_dataframes, ignore_index=True)

# %%
print(df_all_cleaned['Paper Title'].nunique())
df_all_cleaned.head()

# Save the combined DataFrame to a CSV file
# df_all_cleaned.to_csv("03MICCAI_notebook_df_paper_extractions_all_cleaned_.csv", index=False)
# Out:
# 730

# %%
df_all_cleaned = df_all_cleaned.fillna(0)

# Lowercase all text in the 'Text' column
df_all_cleaned['Text'] = df_all_cleaned['Text'].str.lower()
df_all_cleaned['Text'] = df_all_cleaned['Text'].apply(wrap_text, width = 80)

# Regular expression with str.replace to remove the volume information
df_all_cleaned['Paper Title'] = df_all_cleaned['Paper Title'].str.replace(r'\s*\(vol\d+\)', '', regex=True)

df_all_cleaned.rename(columns={'Paper Title': 'title', 'Header Number':'header_no', 'Header Title': 'header_title', 'Text':'text', 'Volume': 'volume'}, inplace=True)

df_all_cleaned.to_csv('03MICCAI_notebook_df_paper_extractions_all_cleaned_.csv', index=False)

# %%
# Search for 'cancer' in the Text column, case insensitive
cancer_papers_mask = df_all_cleaned['text'].str.contains('cancer|tumor|tumour', case=False, na=False)
papers_with_cancer = df_all_cleaned[cancer_papers_mask]

# Get the unique titles of papers that mention 'cancer'
unique_titles_with_cancer = papers_with_cancer['title'].unique()

# Extract all headers and their related text for papers that mention 'cancer'
extracted_info = pd.DataFrame()
for title in unique_titles_with_cancer:
    paper_info = df_all_cleaned[df_all_cleaned['title'] == title]
    extracted_info = pd.concat([extracted_info, paper_info])

# Reset index of the resulting DataFrame
extracted_info.reset_index(drop=True, inplace=True)

unique_paper_titles_with_cancer = extracted_info['title'].unique()
print(len(unique_paper_titles_with_cancer))

# Display the first few rows of the resulting DataFrame
# extracted_info.to_csv("03MICCAI_notebook_df_paper_extractions_cancer.csv", index=False)
extracted_info.head()
# Out:
# 263
#                                                title header_no  header_title  \
# 0  Anatomy-Driven Pathology Detection on Chest X-...       1.0  Introduction
# 1  Anatomy-Driven Pathology Detection on Chest X-...       2.0  Related Work
# 2  Anatomy-Driven Pathology Detection on Chest X-...       3.1         Model
# 3  Anatomy-Driven Pathology Detection on Chest X-...       3.2     Inference
# 4  Anatomy-Driven Pathology Detection on Chest X-...       3.3      Training
#
#                                                 text
# 0  chest radiographs (chest x-rays) represent the...
# 1  weakly supervised pathology detection. due to ...
# 2  figure 1 provides an overview of our method. g...
# 3  during inference, the trained model predicts a...
# 4  the anatomical region detector is trained usin...

# %%
categories = {
    'age': ['age', 'age', 'young', 'old', 'gender'],
    'gender': ['gender', 'sex', 'women', 'woman', 'female', 'male'],
    'ethnicity': ['ethnicity', 'ethnicities', 'race', 'white patients', 'black patients'],
    'location_info': ['geolocation', 'geographical', 'geographic', 'country', 'countries', 
                    'city', 'cities', 'hospital', 'hospitals', 'clinic', 'clinics', 'continent',
                    'province', 'state', 'region', 'town', 'village', 'area', 'district'],
    'patients': ['patient', 'patients'],
    'dataset_info': ['dataset', 'datasets', 'data set', 'data sets', 'publicly', 'public', 'private', 'open access', 'open-access'],
    'bias_info': ['bias', 'biases', 'fairness'],
    
}

# Flatten the list of all keywords excluding 'patients' to avoid redundancy
all_keywords = sum([kw for cat, kw in categories.items() if cat != 'patients'], [])

# Filter papers that mention 'patient' or 'patients'
scope_mask = extracted_info['text'].str.contains('patient|patients', case=False, na=False)
papers_with_patients = extracted_info[scope_mask]

# Prepare a list to collect paper info dictionaries
papers_info_list = []

# Iterate over unique titles in the filtered DataFrame
for title in papers_with_patients['title'].unique():
    paper_info = papers_with_patients[papers_with_patients['title'] == title]
    # Initialize a dictionary for the current paper with zeros for all keywords
    paper_keywords = dict.fromkeys(all_keywords, 0)
    paper_keywords['title'] = title
    # Check for each keyword in the text of the paper
    for keyword in all_keywords:
        if any(paper_info['text'].str.contains(keyword, case=False, na=False)):
            paper_keywords[keyword] = 1
    # Collect the keyword matches for the current paper
    papers_info_list.append(paper_keywords)

# Create a DataFrame from the list of dictionaries
keywords_per_paper = pd.DataFrame(papers_info_list)
# Save the DataFrame to a CSV file for further analysis
# papers_with_patients.to_csv("03MICCAI_notebook_df_paper_extractions_patients_and_cancer.csv", index=False)
print('Number of unique titles for papers containing the keyword <patient/patients>:', len(papers_with_patients['title'].unique()))

papers_with_patients.head()
# Out:
# Number of unique titles for papers containing the keyword <patient/patients>: 155
#                                                 title header_no  \
# 5   Anatomy-Driven Pathology Detection on Chest X-...       3.4
# 18  Self-supervised Learning for Physiologically-B...       2.4
# 20  Self-supervised Learning for Physiologically-B...         0
# 21  Self-supervised Learning for Physiologically-B...       4.0
# 32  AME-CAM: Attentive Multiple-Exit CAM for Weakl...       5.0
#
#              header_title                                               text
# 5                 Dataset  training dataset. we train on the chest imagen...
# 18                Dataset  the dataset is composed of 23 oncological pati...
# 20  (Color figure online)  the most important design choice is the select...
# 21             Discussion  even though the choice of the final activation...
# 32             Conclusion  in this work, we propose a brain tumor segment...

# %%
notebook_name = '03MICCAI_notebook_'

# Check if the number of unique titles is at least 100
unique_titles = papers_with_patients['title'].nunique()
if unique_titles < 100:
    print(f"Warning: Only {unique_titles} unique papers found, less than 100.")

# Randomly select 1000 unique titles
selected_titles = papers_with_patients['title'].drop_duplicates().sample(n=min(100, unique_titles), random_state=32)

# Filter the original DataFrame to include only the selected titles
selected_papers_df = papers_with_patients[papers_with_patients['title'].isin(selected_titles)]

# Save selected_papers_df DataFrame with 100 randomly selected papers and their related rows
#selected_papers_df.to_csv(notebook_name + '100_randomly_selected_papers.csv')

# Print the number of unique titles in the selected DataFrame
print(f"Number of unique titles in the selected DataFrame: {selected_papers_df['title'].nunique()}")
# Out:
# Number of unique titles in the selected DataFrame: 100
