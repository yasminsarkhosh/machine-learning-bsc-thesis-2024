# %% [markdown]
# #### Objective of the Notebook:
# The notebook is designed to automate the extraction and processing of data from HTML documents that contain information about MICCAI 2023 conference papers. It aims to streamline the gathering of details such as titles, authors, DOIs, and page numbers from web-scraped HTML content, organize this information into structured data formats, and ensure its usability for further analysis or reference.
#
# MICCAI 2023 webpage: https://conferences.miccai.org/2023/papers/, listing the 730 submitted papers.
#
# The 730 research articles are divided into 10 PDF volumes: https://link.springer.com/book/10.1007/978-3-031-43907-0.
#
# #### Input Data Expected:
# 1. **HTML Documents**: The input for this notebook consists of HTML files saved as `.doc` files. Each document corresponds to a page from the table of contents of the MICCAI 2023 conference volumes, detailing titles, authors, DOIs, and page numbers of the conference papers.
#     - In total there is 41 .doc files containing HTML code: [MICCAI 2023 .doc files with HTML code](<../../../miccai2023 papers>)
# 2. **Directory Paths**: The paths where these HTML documents are stored need to be provided. The notebook expects a structured directory containing these documents for each volume of the conference proceedings.
#
# #### Output Data/Files Generated:
# 1. **Dataframes**: The primary output is a Pandas dataframe containing cleaned and structured data extracted from the HTML documents. This dataframe includes columns for paper titles, authors, page numbers, DOIs, publication years, and volume numbers.
# 2. **CSV File**: The cleaned and consolidated dataframe is saved as a CSV file named `database_miccai_<year>.csv`, where `<year>` represents the year of the conference. This file contains all the information ready for further analysis or archival purposes.
#
# #### Assumptions or Important Notes:
# 1. **Pre-processed HTML Documents**: It is assumed that the HTML content from the web pages has been manually copied and saved into `.doc` files accurately without any alterations that could affect the structure of the information.
# 2. **Manual Handling of HTML**: The method of acquiring HTML content involves manual copying and pasting, which may introduce human error or inconsistencies in how data is formatted or saved.
# 3. **File Naming Convention**: The notebook assumes a specific naming convention for the HTML files, which includes details about the volume and page number. Any deviation from this naming convention might require modifications to the file-processing logic in the notebook.
# 4. **HTML Structure Dependence**: The extraction functions rely heavily on the structure of the HTML documents being consistent across all files. Changes in the webpage layout or HTML structure in future conferences will require adjustments to the scraping logic.
# 5. **Exclusion Criteria**: Specific page numbers known to contain irrelevant information (like front and back matter) are programmatically excluded during processing to ensure the cleanliness of the dataset.

# %% [markdown]
# # Automated Data Extraction and Processing of MICCAI 2023 Conference Papers
# ***

# %% [markdown]
# Libraries and functions

# %%
# pdf webscrapping and text extraction
from bs4 import BeautifulSoup

# get the pdf files or url from the web
import requests

# input output operations
import io

#!pip install xhtml2pdf requests
#!pip install lxml

# for converting html to pdf
import regex as re
import pandas as pd
from urllib.request import urlopen
from urllib import request as urllib2
import numpy as np

# %% [markdown]
# Main function for text mining relevant information from MICCAI 2023 HTML files into a dataframe
# ***

# %%
pd.set_option('display.max_rows', None)

# %%
#helper function to find lines in html document with DOI and titles of articles
def has_doi(href):
    return href and re.compile("chapter/").search(href)

# %%
#main mining function returning the initial dataframe 
def mining(html_doc, year, current_page, all_pages, part):
    #opening the html document (copy pasted and saved as a .doc file)
    doc = open(html_doc, "r", encoding = "ISO-8859-1") 
    soup = BeautifulSoup(doc, 'html.parser' )

    list_of_doi = soup.find_all(href=has_doi)
        
    #getting the titles and the doi's from list generated helper function
    titles = []
    doi_str = []

    for element in list_of_doi:
        titles.append(element.get_text()) #returns the titles as the only text in the list
        string = str(element)
        first_substring = '/chapter'
        second_substring ='">'
        #separates out the DOIS (added the +9 to remove /chapter/ from the beginning of all DOIS)
        doi_str.append(string[(string.find(first_substring)+9):string.find(second_substring)]) 
                
    ## now the lines containing author are found
    authors = soup.find_all("li", class_="c-author-list__item")
        
    #keeping only the author names
    authors_str = []
    for element in authors:
        string = str(element)
        first_substring = 'item">'
        second_substring ='</li>'
        authors_str.append(string[(string.find(first_substring)+6):string.find(second_substring)])

    #now the lines containing page numbers are found
    page_numbers= soup.find_all('div', class_ = "c-meta")

    #keeping only the page numbers
    page_numbers_str = []

    # an element in page_numbers_str looks like this:
    '''' <div class="c-meta"><span class="c-meta__item u-display-inline-block" 
    data-test="page-number"> Pages 618-627</span> </div> '''  

    for element in page_numbers:            
        #removes white spaces, and everything within the div tag that is not the page numbers
        string = element.get_text()[6:-1]                       #618-627
        #splits the string into two numbers
        both = string.split("-")                                #['618', '627']
        #filtering out front matters and back matters                                                   
        if 'x' and '1-1' and '463-463' and '135-135' and '649-649' and '247-247' and '281-281' and '369-369' and '433-433' and '509-509' and '583-583' and '757-757' and '535-535' not in string:             
            try: 
                if int(both[1])-int(both[0]) > 1: 
                    page_numbers_str.append(string)              #if True adds the string to the list

            except:
                if "C1" in string or "C" in string:              #page numbers that are in the form of C<some number> 
                    page_numbers_str.append(string)
        
        #filtering out back matters
        if int(current_page) == int(all_pages) and '781-785' in string: 
            page_numbers_str = page_numbers_str[:-1]
        elif int(current_page) == int(all_pages) and '787-791' in string:
            page_numbers_str = page_numbers_str[:-1]
        elif int(current_page) == int(all_pages) and '767-771' in string:
            page_numbers_str = page_numbers_str[:-1]
        elif int(current_page) == int(all_pages) and '797-801' in string:  
            page_numbers_str = page_numbers_str[:-1]
        elif int(current_page) == int(all_pages) and '801-806' in string:
            page_numbers_str = page_numbers_str[:-1]
        elif int(current_page) == int(all_pages) and '813-818' in string:
            page_numbers_str = page_numbers_str[:-1]
        elif int(current_page) == int(all_pages) and '687-690' in string:
            page_numbers_str = page_numbers_str[:-1]
        elif int(current_page) == int(all_pages) and '739-743' in string:
            page_numbers_str = page_numbers_str[:-1]
        elif int(current_page) == int(all_pages) and '791-795' in string:
            page_numbers_str = page_numbers_str[:-1]


    #need to create a list of the year of publication to add to dataframe 
    year_of_pub = []
    for element in titles:
        year_of_pub.append(year)
    
    #will add the part of the publication to the dataframe as well
    part_of_pub = []
    for element in titles:
        part_of_pub.append(part)
        
    #creating the column names and content for the dataframe        
    data = {'Title': titles,
        'Authors': authors_str,
        'Page numbers' : page_numbers_str,
        'DOI': doi_str,
        'Year of publication' : year_of_pub,
        'Part of publication' : part_of_pub       }

    df = pd.DataFrame(data)

    return df

# %%
def clean_df(df):    
    # Sorting by 'Title' and resetting the index
    df.sort_values(by='Title', inplace=True)
    df.reset_index(drop=True, inplace=True)

    # Adding 'paper_id' as the first column
    df.insert(0, 'paper_id', range(1, len(df) + 1))

    # Rename/refine the columns of the dataframe to make it more accessible for further use and analysis
    df.rename(columns={'Title': 'title', 'Part of publication': 'vol_number', 'Authors': 'authors', 
                   'DOI': 'doi', 'Year of publication': 'publication_year','Page numbers': 'page_numbers'}, inplace=True)   

    # Filtering out rows where 'page_numbers' is 'C1-C1'
    df = df[df['page_numbers'] != 'C1-C1']

    # Direct conversion to ensure 'vol_number' is treated as an integer
    df.loc[:, 'vol_number'] = pd.to_numeric(df['vol_number'], errors='coerce').fillna(0).astype(int)
    
    # Proceed with sorting, cleaning, and other preparation steps as before
    vol_counts = df['vol_number'].value_counts()
    
    # Using a loop to print the number of papers by volume, safely handling missing volumes
    for vol in range(1, 11):
        # Use .get(vol, default_value) to safely access the count for each volume
        print(f"Number of papers in Volume {vol}:", vol_counts.get(vol, 0))


    # Printing the total number of papers
    print('Total number of papers:', len(df))

    return df

# %%
#helper function to combine all df together
def data_together(data, year):
    combined_frame = pd.concat(data, ignore_index = True, sort = False)
    combined_frame_refined = clean_df(combined_frame)
    combined_frame_refined.to_csv('/Users/yasminsarkhosh/Documents/GitHub/machine-learning-bsc-thesis-2024/code/databases/database_miccai_'+ str(year) +'.csv')
   
    return combined_frame_refined

# %%
"""
miccai 2023 papers : 10 volumes in total 
base path to the folder with stored HTML docs:
"""


miccai =[
    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 01 page 1 of 4.doc',
    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 01 page 2 of 4.doc',
    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 01 page 3 of 4.doc',
    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 01 page 4 of 4.doc',

    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 02 page 1 of 4.doc',
    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 02 page 2 of 4.doc',
    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 02 page 3 of 4.doc',
    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 02 page 4 of 4.doc',

    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 03 page 1 of 4.doc',
    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 03 page 2 of 4.doc',
    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 03 page 3 of 4.doc',
    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 03 page 4 of 4.doc',

    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 04 page 1 of 4.doc',
    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 04 page 2 of 4.doc',
    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 04 page 3 of 4.doc',
    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 04 page 4 of 4.doc',

    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 05 page 1 of 4.doc',
    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 05 page 2 of 4.doc',
    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 05 page 3 of 4.doc',
    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 05 page 4 of 4.doc',

    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 06 page 1 of 4.doc',
    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 06 page 2 of 4.doc',
    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 06 page 3 of 4.doc',
    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 06 page 4 of 4.doc',

    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 07 page 1 of 5.doc',
    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 07 page 2 of 5.doc',
    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 07 page 3 of 5.doc',
    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 07 page 4 of 5.doc',
    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 07 page 5 of 5.doc',

    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 08 page 1 of 4.doc',
    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 08 page 2 of 4.doc',
    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 08 page 3 of 4.doc',
    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 08 page 4 of 4.doc',

    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 09 page 1 of 4.doc',
    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 09 page 2 of 4.doc',
    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 09 page 3 of 4.doc',
    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 09 page 4 of 4.doc',

    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 10 page 1 of 4.doc',
    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 10 page 2 of 4.doc',
    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 10 page 3 of 4.doc',
    '/Users/yasminsarkhosh/Documents/miccai2023 papers/miccai2023 vol 10 page 4 of 4.doc',     
    ]

# %%
data = []
for element in miccai:
    data.append(mining(element, 2023, element[-10], element[-5],  element[-18:-16]))

data_together(data, 2023)
# Out:
# Number of papers in Volume 1: 73
# Number of papers in Volume 2: 73
# Number of papers in Volume 3: 72
# Number of papers in Volume 4: 75
# Number of papers in Volume 5: 76
# Number of papers in Volume 6: 77
# Number of papers in Volume 7: 75
# Number of papers in Volume 8: 65
# Number of papers in Volume 9: 70
# Number of papers in Volume 10: 74
# Total number of papers: 730
#      paper_id                                              title  \
# 0           1  3D Arterial Segmentation via Single 2D Project...
# 1           2  3D Dental Mesh Segmentation Using Semantics-Ba...
# 2           3  3D Medical Image Segmentation with Sparse Anno...
# 3           4  3D Mitochondria Instance Segmentation with Spa...
# 4           5  3D Teeth Reconstruction from Panoramic Radiogr...
# 5           6  A Closed-Form Solution to Electromagnetic Sens...
# 6           7  A Conditional Flow Variational Autoencoder for...
# 7           8  A Coupled-Mechanisms Modelling Framework for N...
# 8           9  A Denoised Mean Teacher for Domain Adaptive Po...
# 9          10  A Flexible Framework for Simulating and Evalua...
# 10         11  A General Stitching Solution for Whole-Brain 3...
# 11         12  A Model-Agnostic Framework for Universal Anoma...
# 12         13  A Modulatory Elongated Model for Delineating R...
# 13         14  A Motion Transformer for Single Particle Track...
# 14         15  A Multi-task Method for Immunofixation Electro...
# 15         16  A Multi-task Network for Anatomy Identificatio...
# 16         17  A Multimodal Disease Progression Model for Gen...
# 17         18  A Novel Multi-task Model Imitating Dermatologi...
# 18         19  A Novel Video-CTU Registration Method with Str...
# 19         20  A One-Class Variational Autoencoder (OCVAE) Ca...
# 20         21  A Patient-Specific Self-supervised Model for A...
# 21         22  A Privacy-Preserving Walk in the Latent Space ...
# 22         23  A Reliable and Interpretable Framework of Mult...
# 23         24  A Semantic-Guided and Knowledge-Based Generati...
# 24         25  A Sheaf Theoretic Perspective for Robust Prost...
# 25         26  A Small-Sample Method with EEG Signals Based o...
# 26         27  A Spatial-Temporal Deformable Attention Based ...
# 27         28  A Spatial-Temporally Adaptive PINN Framework f...
# 28         29  A Style Transfer-Based Augmentation Framework ...
# 29         30  A Texture Neural Network to Predict the Abnorm...
# 30         31  A Transfer Learning Approach to Localising a D...
# 31         32  A Unified Deep-Learning-Based Framework for Co...
# 32         33  A Video-Based End-to-end Pipeline for Non-nutr...
# 33         34  A2FSeg: Adaptive Multi-modal Fusion Network fo...
# 34         35  ACC-UNet: A Completely Convolutional UNet Mode...
# 35         36  ACT-Net: Anchor-Context Action Detection in Su...
# 36         37  ACTION++: Improving Semi-supervised Medical Im...
# 37         38  ALL-IN: A Local GLobal Graph-Based DIstillatio...
# 38         39  AMAE: Adaptation of Pre-trained Masked Autoenc...
# 39         40  AME-CAM: Attentive Multiple-Exit CAM for Weakl...
# 40         41  AR2T: Advanced Realistic Rendering Technique f...
# 41         42  ASC: Appearance and Structure Consistency for ...
# 42         43  ASCON: Anatomy-Aware Supervised Contrastive Le...
# 43         44  AUA-dE: An Adaptive Uncertainty Guided Attenti...
# 44         45  Accurate Multi-contrast MRI Super-Resolution v...
# 45         46  Accurate and Robust Patient Height and Weight ...
# 46         47  Acute Ischemic Stroke Onset Time Classificatio...
# 47         48  Adapter Learning in Pretrained Feature Extract...
# 48         49  Adaptive Multi-scale Online Likelihood Network...
# 49         50  Adaptive Region Selection for Active Learning ...
# 50         51  Adaptive Supervised PatchNCE Loss for Learning...
# 51         52  Additional Positive Enables Better Representat...
# 52         53  Adjustable Robust Transformer for High Myopia ...
# 53         54  Adult-Like Phase and Multi-scale Assistance fo...
# 54         55  AirwayFormer: Structure-Aware Boundary-Adaptiv...
# 55         56  Alias-Free Co-modulated Network for Cross-Moda...
# 56         57  An AI-Ready Multiplex Staining Dataset for Rep...
# 57         58  An Anti-biased TBSRTC-Category Aware Nuclei Se...
# 58         59  An Auto-Encoder to Reconstruct Structure with ...
# 59         60  An Automated Pipeline for Quantitative T2* Fet...
# 60         61  An Explainable Deep Framework: Towards Task-Sp...
# 61         62  An Explainable Geometric-Weighted Graph Attent...
# 62         63  An Interpretable and Attention-Based Method fo...
# 63         64  An Unsupervised Multispectral Image Registrati...
# 64         65  Analysis of Suture Force Simulations for Optim...
# 65         66  Anatomical Landmark Detection Using a Multires...
# 66         67  Anatomical-Aware Point-Voxel Network for Couin...
# 67         68  Anatomy-Driven Pathology Detection on Chest X-...
# 68         69  Anatomy-Informed Data Augmentation for Enhance...
# 69         70        Aneurysm Pose Estimation with Deep Learning
# 70         71  AngioMoCo: Learning-Based Motion Correction in...
# 71         72  Annotator Consensus Prediction for Medical Ima...
# 72         73  Anti-adversarial Consistency Regularization fo...
# 73         74  ArSDM: Colonoscopy Images Synthesis with Adapt...
# 74         75  Ariadnes Thread: Using Text Prompts to Improv...
# 75         76  Artifact Restoration in Histology Images with ...
# 76         77  Assignment Theory-Augmented Neural Network for...
# 77         78  Asymmetric Contour Uncertainty Estimation for ...
# 78         79  Attentive Deep Canonical Correlation Analysis ...
# 79         80  Automated CT Lung Cancer Screening Workflow Us...
# 80         81  Automatic Bleeding Risk Rating System of Gastr...
# 81         82  Automatic Retrieval of Corresponding US Views ...
# 82         83  Automatic Segmentation of Internal Tooth Struc...
# 83         84  Automatic Surgical Reconstruction for Orbital ...
# 84         85  B-Cos Aligned Transformers Learn Human-Interpr...
# 85         86  BerDiff: Conditional Bernoulli Diffusion Model...
# 86         87  Beyond the Snapshot: Brain Tokenized Graph Tra...
# 87         88  Bidirectional Mapping with Contrastive Learnin...
# 88         89  BigFUSE: Global Context-Aware Image Fusion in ...
# 89         90  Black-box Domain Adaptative Cell Segmentation ...
# 90         91  Boosting Breast Ultrasound Video Classificatio...
# 91         92  Boundary Difference over Union Loss for Medica...
# 92         93  Boundary-Weighted Logit Consistency Improves C...
# 93         94  Brain Anatomy-Guided MRI Analysis for Assessin...
# 94         95  BrainUSL: Unsupervised Graph Structure Learnin...
# 95         96  Breast Ultrasound Tumor Classification Using a...
# 96         97  Bridging Ex-Vivo Training and Intra-operative ...
# 97         98  Building a Bridge: Close the Domain Gap in CT ...
# 98         99  CARL: Cross-Aligned Representation Learning fo...
# 99        100  CAS-Net: Cross-View Aligned Segmentation by Gr...
# 100       101  CAT-ViL: Co-attention Gated Vision-Language Em...
# 101       102  CDiffMR: Can We Replace the Gaussian Noise wit...
# 102       103  CL-ADDA: Contrastive Learning with Amplitude-D...
# 103       104  CLIP-Lung: Textual Knowledge-Guided Lung Nodul...
# 104       105  COLosSAL: A Benchmark for Cold-Start Active Le...
# 105       106  COVID-19 Pneumonia Classification with Transfo...
# 106       107  CT Kernel Conversion Using Multi-domain Image-...
# 107       108  CT-Guided, Unsupervised Super-Resolution Recon...
# 108       109  CTFlow: Mitigating Effects of Computed Tomogra...
# 109       110  CXR-CLIP: Toward Large Scale Chest X-ray Langu...
# 110       111  Can Point Cloud Networks Learn Statistical Sha...
# 111       112  Cascade Transformer Encoded Boundary-Aware Mul...
# 112       113  Category-Independent Visual Explanation for Me...
# 113       114  Category-Level Regularized Unlabeled-to-Labele...
# 114       115  CellGAN: Conditional Cervical Cell Synthesis f...
# 115       116  CenterlinePointNet++: A New Point Cloud Based ...
# 116       117  Centroid-Aware Feature Recalibration for Cance...
# 117       118  Certification of Deep Learning Models for Medi...
# 118       119  CheXstray: A Real-Time Multi-Modal Monitoring ...
# 119       120  Chest X-ray Image Classification: A Causal Per...
# 120       121  CircleFormer: Circular Nuclei Detection in Who...
# 121       122  Class Specific Feature Disentanglement and Tex...
# 122       123  Class-Aware Feature Alignment for Domain Adapt...
# 123       124  Client-Level Differential Privacy via Adaptive...
# 124       125  Clinical Evaluation of AI-Assisted Virtual Con...
# 125       126  Cluster-Induced Mask Transformers for Effectiv...
# 126       127  Clustering Disease Trajectories in Contrastive...
# 127       128         Co-assistant Networks for Label Correction
# 128       129  Co-learning Semantic-Aware Unsupervised Segmen...
# 129       130  CoLa-Diff: Conditional Latent Diffusion Model ...
# 130       131  CoactSeg: Learning from Heterogeneous Data for...
# 131       132  Cochlear Implant Fold Detection in Intra-opera...
# 132       133  Collaborative Modality Generation and Tissue S...
# 133       134  Combat Long-Tails in Medical Classification wi...
# 134       135  Combating Medical Label Noise via Robust Semi-...
# 135       136  Community-Aware Transformer for Autism Predict...
# 136       137  Computationally Efficient 3D MRI Reconstructio...
# 137       138  ConTrack: Contextual Transformer for Device Tr...
# 138       139  Conditional Diffusion Models for Weakly Superv...
# 139       140  Conditional Physics-Informed Graph Neural Netw...
# 140       141  Conditional Temporal Attention Networks for Ne...
# 141       142  Consistency-Guided Meta-learning for Bootstrap...
# 142       143  Content-Preserving Diffusion Model for Unsuper...
# 143       144  Context-Aware Pseudo-label Refinement for Sour...
# 144       145  Continual Learning for Abdominal Multi-organ a...
# 145       146  Contrastive Diffusion Model with Auxiliary Gui...
# 146       147  Contrastive Feature Decoupling for Weakly-Supe...
# 147       148  Contrastive Masked Image-Text Modeling for Med...
# 148       149  ConvFormer: Plug-and-Play CNN-Style Transforme...
# 149       150  Convolving Directed Graph Edges via Hodge Lapl...
# 150       151  CorSegRec: A Topology-Preserving Scheme for Ex...
# 152       153  Correlation-Aware Mutual Learning for Semi-sup...
# 153       154  CortexMorph: Fast Cortical Thickness Estimatio...
# 154       155  Cortical Analysis of Heterogeneous Clinical Br...
# 155       156  Coupling Bracket Segmentation and Tooth Surfac...
# 156       157  Cross-Adversarial Local Distribution Regulariz...
# 157       158  Cross-Dataset Adaptation for Instrument Classi...
# 158       159  Cross-Modulated Few-Shot Image Generation for ...
# 159       160  Cross-View Deformable Transformer for Non-disp...
# 160       161  CycleSTTN: A Learning-Based Temporal Model for...
# 161       162  DARC: Distribution-Aware Re-Coloring Model for...
# 162       163  DAS-MIL: Distilling Across Scales for MIL Clas...
# 163       164  DAST: Differentiable Architecture Search with ...
# 164       165  DBTrans: A Dual-Branch Vision Transformer for ...
# 165       166  DCAug: Domain-Aware and Content-Consistent Cro...
# 166       167  DHC: Dual-Debiased Heterogeneous Co-training F...
# 167       168  DISA: DIfferentiable Similarity Approximation ...
# 168       169  DMCVR: Morphology-Guided Diffusion Model for 3...
# 169       170  DOMINO++: Domain-Aware Loss Regularization for...
# 170       171  DRMC: A Generalist Model with Dynamic Routing ...
# 171       172  DULDA: Dual-Domain Unsupervised Learned Descen...
# 172       173  Data AUDIT: Identifying Attribute Utility- and...
# 173       174                    DeDA: Deep Directed Accumulator
# 174       175  Debiasing Medical Visual Question Answering vi...
# 175       176  Deblurring Masked Autoencoder Is Better Recipe...
# 176       177  Decoupled Consistency for Semi-supervised Medi...
# 177       178  Deep Cellular Embeddings: An Explainable Plug ...
# 178       179  Deep Homography Prediction for Endoscopic Came...
# 179       180  Deep Learning for Tumor-Associated Stroma Iden...
# 180       181  Deep Learning-Based Air Trapping Quantificatio...
# 181       182  Deep Learning-Based Anonymization of Chest Rad...
# 182       183  Deep Mutual Distillation for Semi-supervised M...
# 183       184  Deep Probability Contour Framework for Tumour ...
# 184       185  Deep Reinforcement Learning Based System for I...
# 185       186  Deep Unsupervised Clustering for Conditional I...
# 186       187  DeepGraphDMD: Interpretable Spatio-Temporal De...
# 187       188  DeepSOZ: A Robust Deep Model for Joint Tempora...
# 188       189  Democratizing Pathological Image Segmentation ...
# 189       190  Dense Transformer based Enhanced Coding Networ...
# 190       191  Deployment of Image Analysis Algorithms Under ...
# 191       192  Detecting Domain Shift in Multiple Instance Le...
# 192       193  Detecting the Sensing Area of a Laparoscopic P...
# 193       194  Detection of Basal Cell Carcinoma in Whole Sli...
# 194       195  Detection-Free Pipeline for Cervical Cancer Sc...
# 195       196  Developing Large Pre-trained Model for Breast ...
# 196       197  Development and Fast Transferring of General C...
# 197       198  Devil is in Channels: Contrastive Single Domai...
# 198       199  DiMix: Disentangle-and-Mix Based Domain Genera...
# 199       200  Dice Semimetric Losses: Optimizing the Dice Sc...
# 200       201  DiffDP: Radiotherapy Dose Prediction via a Dif...
# 201       202  DiffMIC: Dual-Guidance Diffusion Network for M...
# 202       203  DiffMix: Diffusion Model-Based Data Synthesis ...
# 203       204      DiffULD: Diffusive Universal Lesion Detection
# 204       205  Differentiable Beamforming for Ultrasound Auto...
# 205       206  DiffuseIR: Diffusion Models for Isotropic Reco...
# 206       207  Diffusion Kinetic Model for Breast Cancer Segm...
# 207       208  Diffusion Transformer U-Net for Medical Image ...
# 208       209  Diffusion-Based Data Augmentation for Nuclei I...
# 209       210  Diffusion-Based Hierarchical Multi-label Objec...
# 210       211  DisAsymNet: Disentanglement of Asymmetrical Ab...
# 211       212  DisC-Diff: Disentangled Conditional Diffusion ...
# 212       213  Discovering Brain Network Dysfunction in Alzhe...
# 213       214  Disentangling Site Effects with Cycle-Consiste...
# 214       215  Distilling BlackBox to Interpretable Models fo...
# 215       216  Distributionally Robust Image Classifiers for ...
# 216       217  Diversity-Preserving Chest Radiographs Generat...
# 217       218  Do We Really Need that Skip-Connection? Unders...
# 218       219  Domain Adaptation for Medical Image Segmentati...
# 219       220  Domain-Agnostic Segmentation of Thalamic Nucle...
# 220       221  Dose Guidance for Radiotherapy-Oriented Deep L...
# 221       222  Dual Arbitrary Scale Super-Resolution for Mult...
# 222       223  Dual Conditioned Diffusion Models for Out-of-D...
# 223       224  Dual Domain Motion Artifacts Correction for MR...
# 224       225  Dynamic Curriculum Learning via In-Domain Unce...
# 225       226            Dynamic Functional Connectome Harmonics
# 226       227  Dynamic Graph Neural Representation Based Mult...
# 227       228  Dynamic Structural Brain Network Construction ...
# 228       229  ECL: Class-Enhancement Contrastive Learning fo...
# 229       230  EGE-UNet: An Efficient Group Enhanced UNet for...
# 230       231  EPVT: Environment-Aware Prompt Vision Transfor...
# 231       232  EchoGLAD: Hierarchical Graph Neural Networks f...
# 232       233  Edge-Aware Multi-task Network for Integrating ...
# 233       234  EdgeAL: An Edge Estimation Based Active Learni...
# 234       235  EdgeMixup: Embarrassingly Simple Data Alterati...
# 235       236  Efficient Spatiotemporal Learning of Microscop...
# 236       237  Efficient Subclass Segmentation in Medical Images
# 237       238  Elongated Physiological Structure Segmentation...
# 238       239  Enabling Geometry Aware Learning Through Diffe...
# 239       240  Encoding Surgical Videos as Latent Spatiotempo...
# 240       241  EndoSurf: Neural Surface Reconstruction of Def...
# 241       242  Enhance Early Diagnosis Accuracy of Alzheimer...
# 242       243  Enhancing Automatic Placenta Analysis Through ...
# 243       244  Enhancing Breast Cancer Risk Prediction by Inc...
# 244       245  EoFormer: Edge-Oriented Transformer for Brain ...
# 245       246  Estimated Time to Surgical Procedure Completio...
# 246       247  Estimation of 3T MR Images from 1.5T Images Re...
# 247       248  Evidence Reconciled Neural Network for Out-of-...
# 248       249  Evolutionary Normalization Optimization Boosts...
# 249       250  Explainable Image Classification with Improved...
# 250       251  Explaining Massive-Training Artificial Neural ...
# 251       252  Exploring Brain Function-Structure Connectome ...
# 252       253  Exploring Unsupervised Cell Recognition with P...
# 253       254  Eye-Guided Dual-Path Network for Multi-organ S...
# 254       255  FE-STGNN: Spatio-Temporal Graph Neural Network...
# 255       256  FEDD - Fair, Efficient, and Diverse Diffusion-...
# 256       257  FLIm-Based in Vivo Classification of Residual ...
# 257       258  FSDiffReg: Feature-Wise and Score-Wise Diffusi...
# 258       259  Factor Space and Spectrum for Medical Hyperspe...
# 259       260  FairAdaBN: Mitigating Unfairness with Adaptive...
# 260       261  Faithful Synthesis of Low-Dose Contrast-Enhanc...
# 261       262  Fast Non-Markovian Diffusion Model for Weakly ...
# 262       263  Fast Reconstruction for Deep Learning PET Head...
# 263       264  FeSViBS: Federated Split Learning of Vision Tr...
# 264       265  Feature-Conditioned Cascaded Video Diffusion M...
# 265       266  FedContrast-GPA: Heterogeneous Federated Optim...
# 266       267  FedGrav: An Adaptive Federated Aggregation Alg...
# 267       268  FedIIC: Towards Robust Federated Learning for ...
# 268       269  FedSoup: Improving Generalization and Personal...
# 269       270  Federated Condition Generalization on Low-dose...
# 270       271  Federated Uncertainty-Aware Aggregation for Fu...
# 271       272  Few Shot Medical Image Segmentation with Cross...
# 272       273  Few-Shot Medical Image Segmentation via a Regi...
# 273       274  Fine-Grained Hand Bone Segmentation via Adapti...
# 274       275  Fine-Tuning Network in Federated Learning for ...
# 275       276  Flexible Unfolding of Circular Structures for ...
# 276       277  Flow-Based Geometric Interpolation of Fiber Or...
# 277       278  FocalErrorNet: Uncertainty-Aware Focal Modulat...
# 278       279  FocalUNETR: A Focal Transformer for Boundary-A...
# 279       280  Forensic Histopathological Recognition via a C...
# 280       281  Forward-Solution Aided Deep-Learning Framework...
# 281       282  Foundation Ark: Accruing and Reusing Knowledge...
# 282       283  Foundation Model for Endoscopy Video Analysis ...
# 283       284  Fourier Test-Time Adaptation with Multi-level ...
# 284       285  FreeSeed: Frequency-Band-Aware and Self-guided...
# 285       286  Frequency Domain Adversarial Training for Robu...
# 286       287  Frequency-Mixed Single-Source Domain Generaliz...
# 287       288          From Mesh Completion to AI Designed Crown
# 288       289  From Sparse to Precise: A Practical Editing Ap...
# 289       290  From Tissue to Sound: Model-Based Sonification...
# 290       291  Full Image-Index Remainder Based Single Low-Do...
# 291       292                         Fully Bayesian VIB-DeepSSM
# 292       293  Fundus-Enhanced Disease-Aware Distillation Mod...
# 293       294  GL-Fusion: Global-Local Fusion Network for Mul...
# 294       295  GRACE: A Generalized and Personalized Federate...
# 295       296  GSDG: Exploring a Global Semantic-Guided Dual-...
# 296       297  GSMorph: Gradient Surgery for Cine-MRI Cardiac...
# 297       298  Gadolinium-Free Cardiac MRI Myocardial Scar De...
# 298       299  Gall Bladder Cancer Detection from US Images w...
# 299       300  Gene-Induced Multimodal Pre-training for Image...
# 300       301  Generating High-Resolution 3D CT with 12-Bit D...
# 301       302  Generating Realistic Brain MRIs via a Conditio...
# 302       303       Geometric Ultrasound Localization Microscopy
# 303       304  Geometry-Adaptive Network for Robust Detection...
# 304       305           Geometry-Invariant Abnormality Detection
# 305       306  Global k-Space Interpolation for Dynamic MRI R...
# 306       307  Gradient and Feature Conformity-Steered Medica...
# 307       308  Graph Convolutional Network with Morphometric ...
# 308       309  Graph-Theoretic Automatic Lesion Tracking and ...
# 309       310  Guiding the Guidance: A Comparative Analysis o...
# 310       311  H-DenseFormer: An Efficient Hybrid Densely Con...
# 311       312  HACL-Net: Hierarchical Attention and Contrasti...
# 312       313  HC-Net: Hybrid Classification Network for Auto...
# 313       314  HENet: Hierarchical Enhancement Network for Pu...
# 314       315  HIGT: Hierarchical Interaction Graph-Transform...
# 315       316  HartleyMHA: Self-attention in Frequency Domain...
# 316       317  Hierarchical Vision Transformers for Disease P...
# 317       318  High-Quality Virtual Single-Viewpoint Surgical...
# 318       319  High-Resolution Cranial Defect Reconstruction ...
# 319       320  Histopathology Image Classification Using Deep...
# 320       321  How Does Pruning Impact Long-Tailed Multi-labe...
# 321       322  How Reliable are the Metrics Used for Assessin...
# 322       323  IIB-MIL: Integrated Instance-Level and Bag-Lev...
# 323       324  Identification of Disease-Sensitive Brain Imag...
# 324       325  Image2SSM: Reimagining Statistical Shape Model...
# 325       326  Imitation Learning from Expert Video Data for ...
# 326       327  Implicit Anatomical Rendering for Medical Imag...
# 327       328  Implicit Neural Representations for Joint Deco...
# 328       329  Importance Weighted Variational Cardiac MRI Re...
# 329       330  Improved Flexibility and Interpretability of L...
# 330       331  Improved Multi-shot Diffusion-Weighted MRI wit...
# 331       332  Improved Prognostic Prediction of Pancreatic C...
# 332       333  Improving Automatic Fetal Biometry Measurement...
# 333       334  Improving Image-Based Precision Medicine with ...
# 334       335  Improving Outcome Prediction of Pulmonary Embo...
# 335       336  Improving Pathology Localization: Multi-series...
# 336       337  Incomplete Multimodal Learning for Visual Acui...
# 337       338  Incremental Learning for Heterogeneous Structu...
# 338       339  Inflated 3D Convolution-Transformer for Weakly...
# 339       340  Infusing Physically Inspired Known Operators i...
# 340       341  Instance-Aware Diffusion Model for Gland Segme...
# 341       342  Instructive Feature Enhancement for Dichotomou...
# 342       343           Intelligent Virtual B-Scan Mirror (IVBM)
# 343       344  Inter-slice Consistency for Unpaired Low-Dose ...
# 344       345  Interpretable Deep Biomarker for Serial Monito...
# 345       346  Interpretable Medical Image Classification Usi...
# 346       347  Intra-operative Forecasting of Standing Spine ...
# 347       348  Intraoperative CT Augmentation for Needle-Base...
# 348       349  Inverse Consistency by Construction for Multis...
# 349       350  InverseSR: 3D Brain MRI Super-Resolution Using...
# 350       351  Ischemic Stroke Segmentation from a Cross-Doma...
# 351       352  Iteratively Coupled Multiple Instance Learning...
# 352       353  JCCS-PFGM: A Novel Circle-Supervision Based Po...
# 353       354  Joint Dense-Point Representation for Contour-A...
# 354       355  Joint Optimization of a \(\beta \)-VAE for ECG...
# 355       356  Joint Prediction of Response to Therapy, Molec...
# 356       357  Joint Representation of Functional and Structu...
# 357       358  Joint Segmentation and Sub-pixel Localization ...
# 358       359  Knowledge Boosting: Rethinking Medical Contras...
# 359       360  L3DMC: Lifelong Learning Using Distillation vi...
# 360       361  LABRAD-OR: Lightweight Memory Scene Graphs for...
# 361       362  LLCaps: Learning to Illuminate Low-Light Capsu...
# 362       363  LOTUS: Learning to Optimize Task-Based US Repr...
# 363       364  LSOR: Longitudinally-Consistent Self-Organized...
# 364       365  LUCYD: A Feature-Driven Richardson-Lucy Deconv...
# 365       366  Label-Free Nuclei Segmentation Using Intra-Ima...
# 366       367  Label-Preserving Data Augmentation in Latent S...
# 367       368  Laplacian-Former: Overcoming the Limitations o...
# 368       369  Learnable Cross-modal Knowledge Distillation f...
# 369       370  Learnable Query Initialization for Surgical In...
# 370       371  Learnable Subdivision Graph Neural Network for...
# 371       372  Learned Alternating Minimization Algorithm for...
# 372       373  Learning Asynchronous Common and Individual Fu...
# 373       374  Learning Deep Intensity Field for Extremely Sp...
# 374       375  Learning Expected Appearances for Intraoperati...
# 375       376  Learning Large Margin Sparse Embeddings for Op...
# 376       377  Learning Normal Asymmetry Representations for ...
# 377       378  Learning Ontology-Based Hierarchical Structura...
# 378       379  Learning Reliability of Multi-modality Medical...
# 379       380  Learning Robust Classifier for Imbalanced Medi...
# 380       381  Learning Transferable Object-Centric Diffeomor...
# 381       382  Learning with Domain-Knowledge for Generalizab...
# 382       383  Learning with Synthesized Data for Generalizab...
# 383       384  Lesion-Aware Contrastive Learning for Diabetic...
# 384       385  LightNeuS: Neural Surface Reconstruction in En...
# 385       386  Liver Tumor Screening and Diagnosis in CT with...
# 386       387  Localized Questions in Medical Visual Question...
# 387       388  Localized Region Contrast for Enhancing Self-s...
# 388       389  Longitudinal Multimodal Transformer Integratin...
# 389       390  Low-Dose CT Image Super-Resolution Network wit...
# 390       391  M&M: Tackling False Positives in Mammography w...
# 391       392  M-FLAG: Medical Vision-Language Pre-training w...
# 392       393  M-GenSeg: Domain Adaptation for Target Modalit...
# 393       394  M3D-NCA: Robust 3D Segmentation with Built-In ...
# 394       395  MDA-SR: Multi-level Domain Adaptation Super-Re...
# 395       396  MDViT: Multi-domain Vision Transformer for Sma...
# 396       397  MEPNet: A Model-Driven Equivariant Proximal Ne...
# 397       398  MI-SegNet: Mutual Information-Based US Segment...
# 398       399  MPBD-LSTM: A Predictive Model for Colorectal L...
# 399       400  MRIS: A Multi-modal Retrieval Approach for Ima...
# 400       401  MSKdeX: Musculoskeletal (MSK) Decomposition fr...
# 401       402  MUVF-YOLOX: A Multi-modal Ultrasound Video Fus...
# 402       403  Machine Learning for Automated Mitral Regurgit...
# 403       404  Make-A-Volume: Leveraging Latent Diffusion Mod...
# 404       405  Mammo-Net: Integrating Gaze Supervision and In...
# 405       406  Many Tasks Make Light Work: Learning to Locali...
# 406       407  Masked Frequency Consistency for Domain-Adapti...
# 407       408  Masked Vision and Language Pre-training with U...
# 408       409  Maximum Entropy on Erroneous Predictions: Impr...
# 409       410  Maximum-Entropy Estimation of Joint Relaxation...
# 410       411  MedGen3D: A Deep Generative Framework for Pair...
# 411       412  MedIM: Boost Medical Image Representation via ...
# 412       413  MedNeXt: Transformer-Driven Scaling of ConvNet...
# 413       414  Medical Boundary Diffusion Model for Skin Lesi...
# 414       415  Medical Phrase Grounding with Region-Phrase Co...
# 415       416  Memory Replay for Continual Medical Image Segm...
# 416       417  Merging-Diverging Hybrid Transformer Networks ...
# 417       418  Mesh2SSM: From Surface Meshes to Statistical S...
# 418       419  MetaLR: Meta-tuning of Learning Rates for Tran...
# 419       420  Microstructure Fingerprinting for Heterogeneou...
# 420       421  Minimal-Supervised Medical Image Segmentation ...
# 421       422  Mining Negative Temporal Contexts for False Po...
# 422       423  Mitigating Calibration Bias Without Fixed Attr...
# 423       424  Mitosis Detection from Partial Annotation by D...
# 424       425  Mitral Regurgitation Quantification from Multi...
# 425       426  MixUp-MIL: Novel Data Augmentation for Multipl...
# 426       427  Mixing Temporal Graphs with MLP for Longitudin...
# 427       428  MoCoSR: Respiratory Motion Correction and Supe...
# 428       429  ModeT: Learning Deformable Image Registration ...
# 429       430  Modeling Alzheimers Disease Progression from ...
# 430       431  Modularity-Constrained Dynamic Representation ...
# 431       432  ModusGraph: Automated 3D and 4D Mesh Model Rec...
# 432       433  Morphology-Inspired Unsupervised Gland Segment...
# 433       434  Motion Compensated Unsupervised Deep Learning ...
# 434       435  MulHiST: Multiple Histological Staining for Th...
# 435       436            Multi-Head Multi-Loss Model Calibration
# 436       437  Multi-IMU with Online Self-consistency for Fre...
# 437       438  Multi-Target Domain Adaptation with Prompt Lea...
# 438       439  Multi-modal Pathological Pre-training via Mask...
# 439       440  Multi-modal Semi-supervised Evidential Recycle...
# 440       441  Multi-modal Variational Autoencoders for Norma...
# 441       442  Multi-modality Contrastive Learning for Sarcop...
# 442       443  Multi-objective Point Cloud Autoencoders for E...
# 443       444  Multi-perspective Adaptive Iteration Network f...
# 444       445  Multi-scale Cross-restoration Framework for El...
# 445       446  Multi-scale Prototypical Transformer for Whole...
# 446       447  Multi-scale Self-Supervised Learning for Longi...
# 447       448  Multi-scope Analysis Driven Hierarchical Graph...
# 448       449  Multi-shot Prototype Contrastive Learning and ...
# 449       450  Multi-task Joint Prediction of Infant Cortical...
# 450       451  Multi-task Learning of Histology and Molecular...
# 451       452  Multi-view Guidance for Self-supervised Monocu...
# 452       453  Multi-view Vertebra Localization and Identific...
# 453       454  MultiTalent: A Multi-dataset Approach to Medic...
# 454       455  Multimodal Brain Age Estimation Using Interpre...
# 455       456  Multimodal CT and MR Segmentation of Head and ...
# 456       457  Multimodal Deep Fusion in Hyperbolic Space for...
# 457       458  Multiple Prompt Fusion for Zero-Shot Lesion De...
# 458       459  NASDM: Nuclei-Aware Semantic Histopathology Im...
# 459       460       NISF: Neural Implicit Segmentation Functions
# 460       461  Neural LerPlane Representations for Fast 4D Re...
# 461       462  Neural Pre-processing: A Learning Framework fo...
# 462       463  NeuroExplainer: Fine-Grained Attention Decodin...
# 463       464  Noise Conditioned Weight Modulation for Robust...
# 464       465  Noise2Aliasing: Unsupervised Deep Learning for...
# 465       466  Non-iterative Coarse-to-Fine Transformer Netwo...
# 466       467  Nonuniformly Spaced Control Points Based on Va...
# 467       468  On the Relevance of Temporal Features for Medi...
# 468       469  One-Shot Federated Learning on Medical Data Us...
# 469       470  One-Shot Traumatic Brain Segmentation with Adv...
# 470       471  Open-Ended Medical Visual Question Answering T...
# 471       472  OpenAL: An Efficient Deep Active Learning Fram...
# 472       473  Optical Coherence Elastography Needle for Biom...
# 473       474  Optical Ultrasound Imaging for Endovascular Re...
# 474       475  Optimizing the 3D Plate Shape for Proximal Hum...
# 475       476  Overall Survival Time Prediction of Glioblasto...
# 476       477  PAS-Net: Rapid Prediction of Antibiotic Suscep...
# 477       478  PCMC-T1: Free-Breathing Myocardial T1 Mapping ...
# 478       479  PET Image Denoising with Score-Based Diffusion...
# 479       480  PET-Diffusion: Unsupervised PET Enhancement Ba...
# 480       481  PIViT: Large Deformation Image Registration wi...
# 481       482  PLD-AL: Pseudo-label Divergence-Based Active L...
# 482       483  PMC-CLIP: Contrastive Language-Image Pre-train...
# 483       484  POV-Surgery: A Dataset for Egocentric Hand and...
# 484       485  PROnet: Point Refinement Using Shape-Guided Of...
# 485       486  Parse and Recall: Towards Accurate Lung Nodule...
# 486       487  Partial Vessels Annotation-Based Coronary Arte...
# 487       488  Partially Supervised Multi-organ Segmentation ...
# 488       489  Path-Based Heterogeneous Brain Transformer Net...
# 489       490  Pathology-and-Genomics Multimodal Transformer ...
# 490       491  Patients and Slides are Equal: A Multi-level M...
# 491       492  Pelphix: Surgical Phase Recognition from X-Ray...
# 492       493  Pelvic Fracture Reduction Planning Based on Mo...
# 493       494  Pelvic Fracture Segmentation Using a Multi-sca...
# 494       495  Performance Metrics for Probabilistic Ordinal ...
# 495       496  Personalized Patch-Based Normality Assessment ...
# 496       497  Physics-Based Decoding Improves Magnetic Reson...
# 497       498  Physics-Informed Conditional Autoencoder Appro...
# 498       499  Physics-Informed Neural Networks for Tissue El...
# 499       500  Pick and Trace: Instance Segmentation for Fila...
# 500       501  Pick the Best Pre-trained Model: Towards Trans...
# 501       502  Point Cloud Diffusion Models for Automatic Imp...
# 502       503  Polar Eyeball Shape Net for 3D Posterior Ocula...
# 503       504  Polar-Net: A Clinical-Friendly Model for Alzhe...
# 504       505  Position-Aware Masked Autoencoder for Histopat...
# 505       506  Positive Definite Wasserstein Graph Kernel for...
# 506       507  Pre-operative Survival Prediction of Diffuse G...
# 507       508  Pre-trained Diffusion Models for Plug-and-Play...
# 508       509  Predicting Diverse Functional Connectivity fro...
# 509       510  Prediction of Cognitive Scores by Joint Use of...
# 510       511  Prediction of Infant Cognitive Development wit...
# 511       512  Prior-Driven Dynamic Brain Networks for Multi-...
# 512       513  Privacy-Preserving Early Detection of Epilepti...
# 513       514  Probabilistic Modeling Ensemble Vision Transfo...
# 514       515  Progressive Attention Guidance for Whole Slide...
# 515       516  Progressively Coupling Network for Brain MRI R...
# 516       517  Prompt-Based Grouping Transformer for Nucleus ...
# 517       518  Prompt-MIL: Boosting Multi-instance Learning S...
# 518       519  ProtoASNet: Dynamic Prototypes for Inherently ...
# 519       520  Punctate White Matter Lesion Segmentation in P...
# 520       521  QCResUNet: Joint Subject-Level and Voxel-Level...
# 521       522  RBGNet: Reliable Boundary-Guided Segmentation ...
# 522       523  RCS-YOLO: A Fast and High-Accuracy Object Dete...
# 523       524  RESToring Clarity: Unpaired Retina Image Enhan...
# 524       525  Rad-ReStruct: A Novel VQA Benchmark and Method...
# 525       526  Radiomics-Informed Deep Learning for Classific...
# 526       527  Realistic Endoscopic Illumination Modeling for...
# 527       528  Reconstructing the Hemodynamic Response Functi...
# 528       529  Recruiting the Best Teacher Modality: A Custom...
# 529       530  Rectifying Noisy Labels with Sequential Prior:...
# 530       531  Reflectance Mode Fluorescence Optical Tomograp...
# 531       532  Regressing Simulation to Real: Unsupervised Do...
# 532       533  Regular SE(3) Group Convolutions for Volumetri...
# 533       534  Regularized Kelvinlet Functions to Model Linea...
# 534       535  Relaxation-Diffusion Spectrum Imaging for Prob...
# 535       536  Reliable Multimodality Eye Disease Screening v...
# 536       537  Representation, Alignment, Fusion: A Generic T...
# 537       538  Rethinking Semi-Supervised Federated Learning:...
# 538       539  Retinal Age Estimation with Temporal Fundus Im...
# 539       540  Retinal Thickness Prediction from Multi-modal ...
# 540       541  Reveal to Revise: An Explainable AI Life Cycle...
# 541       542  Revealing Anatomical Structures in PET to Gene...
# 542       543  Reversing the Abnormal: Pseudo-Healthy Generat...
# 543       544  Revisiting Distillation for Continual Learning...
# 544       545  Revisiting Feature Propagation and Aggregation...
# 545       546  Revolutionizing Space Health (Swin-FSR): Advan...
# 546       547  Right for the Wrong Reason: Can Interpretable ...
# 547       548  Robust Cervical Abnormal Cell Detection via Di...
# 548       549  Robust Estimation of the Microstructure of the...
# 549       550  Robust Exclusive Adaptive Sparse Feature Selec...
# 550       551  Robust Hough and Spatial-To-Angular Transform ...
# 551       552  Robust Segmentation via Topology Violation Det...
# 552       553       Robust T-Loss for Medical Image Segmentation
# 553       554  Robust Vertebra Identification Using Simultane...
# 554       555  Robust and Generalisable Segmentation of Subtl...
# 555       556  S2ME: Spatial-Spectral Mutual Teaching and Ens...
# 556       557  S3M: Scalable Statistical Shape Modeling Throu...
# 557       558  SAMConvex: Fast Discrete Optimization for CT R...
# 558       559  SATTA: Semantic-Aware Test-Time Adaptation for...
# 559       560  SCOL: Supervised Contrastive Ordinal Loss for ...
# 560       561  SEDSkill: Surgical Events Driven Method for Sk...
# 561       562  SENDD: Sparse Efficient Neural Depth and Defor...
# 562       563  SFusion: Self-attention Based N-to-One Multimo...
# 563       564  SHISRCNet: Super-Resolution and Classification...
# 564       565  SLPD: Slide-Level Prototypical Distillation fo...
# 565       566  SLPT: Selective Labeling Meets Prompt Tuning o...
# 566       567  SMRD: SURE-Based Robust MRI Reconstruction wit...
# 567       568  SPR-Net: Structural Points Based Registration ...
# 568       569  STAR-Echo: A Novel Biomarker for Prognosis of ...
# 569       570  Scale Federated Learning for Label Set Mismatc...
# 570       571  Scale-Aware Test-Time Click Adaptation for Pul...
# 571       572  Scaling up 3D Kernels with Bayesian Frequency ...
# 572       573  Scribble-Based 3D Multiple Abdominal Organ Seg...
# 573       574  Second-Course Esophageal Gross Tumor Volume Se...
# 574       575  SegNetr: Rethinking the Local-Global Interacti...
# 575       576  Segment Membranes and Nuclei from Histopatholo...
# 576       577  SegmentOR: Obtaining Efficient Operating Room ...
# 577       578  Segmentation Distortion: Quantifying Segmentat...
# 578       579  Segmentation of Kidney Tumors on Non-Contrast ...
# 579       580  Self- and Semi-supervised Learning for Gastros...
# 580       581  Self-Supervised Domain Adaptive Segmentation o...
# 581       582  Self-adaptive Adversarial Training for Robust ...
# 582       583  Self-aware and Cross-Sample Prototypical Learn...
# 583       584  Self-distillation for Surgical Action Recognition
# 584       585  Self-feedback Transformer: A Multi-label Diagn...
# 585       586  Self-pruning Graph Neural Network for Predicti...
# 586       587  Self-supervised Dense Representation Learning ...
# 587       588  Self-supervised Learning for Endoscopic Video ...
# 588       589  Self-supervised Learning for Physiologically-B...
# 589       590  Self-supervised Learning via Inter-modal Recon...
# 590       591  Self-supervised MRI Reconstruction with Unroll...
# 591       592  Self-supervised Polyp Re-identification in Col...
# 592       593  Self-supervised Sim-to-Real Kinematics Reconst...
# 593       594  Semantic Difference Guidance for the Uncertain...
# 594       595  Semantic Segmentation of Surgical Hyperspectra...
# 595       596  Semantic Virtual Shadows (SVS) for Improved Pe...
# 596       597  Semi-supervised Class Imbalanced Deep Learning...
# 597       598  Semi-supervised Domain Adaptive Medical Image ...
# 598       599  Semi-supervised Pathological Image Segmentatio...
# 599       600  Shape-Aware 3D Small Vessel Segmentation with ...
# 600       601  Shape-Based Pose Estimation for Automatic Stan...
# 601       602  Shifting More Attention to Breast Lesion Segme...
# 602       603  SimPLe: Similarity-Aware Propagation Learning ...
# 603       604  Simulation of Arbitrary Level Contrast Dose in...
# 604       605  Simulation-Based Parameter Optimization for Fe...
# 605       606  Single-subject Multi-contrast MRI Super-resolu...
# 606       607  Skin Lesion Correspondence Localization in Tot...
# 607       608  Smooth Attention for Deep Multiple Instance Le...
# 608       609  Soft-Tissue Driven Craniomaxillofacial Surgica...
# 609       610  Solving Low-Dose CT Reconstruction via GAN wit...
# 610       611  Source-Free Domain Adaptation for Medical Imag...
# 611       612  Source-Free Domain Adaptive Fundus Image Segme...
# 612       613  Spatiotemporal Hub Identification in Brain Net...
# 613       614  Spatiotemporal Incremental Mechanics Modeling ...
# 614       615  Spectral Adversarial MixUp for Few-Shot Unsupe...
# 615       616  Speech Audio Synthesis from Tagged MRI and Non...
# 616       617  Spinal Nerve Segmentation Method and Dataset C...
# 617       618  StainDiff: Transfer Stain Styles of Histology ...
# 618       619  StructuRegNet: Structure-Guided Multimodal 2D-...
# 619       620  Structure-Decoupled Adaptive Part Alignment Ne...
# 620       621  Structure-Preserving Instance Segmentation via...
# 621       622  Structure-Preserving Synthesis: MaskGAN for Un...
# 622       623  Structured State Space Models for Multiple Ins...
# 623       624  Style-Based Manifold for Weakly-Supervised Dis...
# 624       625  SurfFlow: A Flow-Based Approach for Rapid and ...
# 625       626  Surgical Action Triplet Detection by Mixed Sup...
# 626       627  Surgical Activity Triplet Recognition via Trip...
# 627       628  Surgical Video Captioning with Mutual-Modal Co...
# 628       629  SurgicalGPT: End-to-End Language-Vision GPT fo...
# 629       630  SwIPE: Efficient and Robust Medical Image Segm...
# 630       631  SwinMM: Masked Multi-view with Swin Transforme...
# 631       632  SwinUNETR-V2: Stronger Swin Transformers with ...
# 632       633  Synthesis of Contrast-Enhanced Breast MRI Usin...
# 633       634  Synthesising Rare Cataract Surgery Samples wit...
# 634       635  Synthetic Augmentation with Large-Scale Uncond...
# 635       636  TCEIP: Text Condition Embedded Regression Netw...
# 636       637  TCL: Triplet Consistent Learning for Odometry ...
# 637       638  TPRO: Text-Prompting-Based Weakly Supervised H...
# 638       639  TSegFormer: 3D Tooth Segmentation in Intraoral...
# 639       640  TabAttention: Learning Attention Conditionally...
# 640       641  TauFlowNet: Uncovering Propagation Mechanism o...
# 641       642  Temporal Uncertainty Localization to Enable Hu...
# 642       643  Tensor-Based Multimodal Learning for Predictio...
# 643       644  Text-Guided Cross-Position Attention for Segme...
# 644       645  Text-Guided Foundation Model Adaptation for Pa...
# 645       646  The Role of Subgroup Separability in Group-Fai...
# 646       647  Thinking Like Sonographers: A Deep CNN Model f...
# 647       648  Thyroid Nodule Diagnosis in Dynamic Contrast-E...
# 648       649  Topology Repairing of Disconnected Pulmonary A...
# 649       650  Topology-Preserving Automatic Labeling of Coro...
# 650       651  Topology-Preserving Computed Tomography Super-...
# 651       652  Toward Fairness Through Fair Multi-Exit Framew...
# 652       653  Towards AI-Driven Radiology Education: A Self-...
# 653       654  Towards Accurate Microstructure Estimation via...
# 654       655  Towards Expert-Amateur Collaboration: Prototyp...
# 655       656  Towards Frugal Unsupervised Detection of Subtl...
# 656       657  Towards Generalizable Diabetic Retinopathy Gra...
# 657       658  Towards Multi-modal Anatomical Landmark Detect...
# 658       659  Towards Novel Class Discovery: A Study in Nove...
# 659       660  Trackerless Volume Reconstruction from Intraop...
# 660       661  Tracking Adaptation to Improve SuperPoint for ...
# 661       662  TractCloud: Registration-Free Tractography Par...
# 662       663  TransLiver: A Hybrid Transformer Model for Mul...
# 663       664  TransNuSeg: A Lightweight Multi-task Transform...
# 664       665  Transfer Learning-Assisted Survival Analysis o...
# 665       666  Transferability-Guided Multi-source Model Adap...
# 666       667  Transformer-Based Annotation Bias-Aware Medica...
# 667       668  Transformer-Based Dual-Domain Network for Few-...
# 668       669  Transformer-Based End-to-End Classification of...
# 669       670  Transformer-Based Tooth Segmentation, Identifi...
# 670       671  Treasure in Distribution: A Domain Randomizati...
# 671       672  Treatment Outcome Prediction for Intracerebral...
# 672       673  TriDo-Former: A Triple-Domain Transformer for ...
# 673       674  Triangular Analysis of Geographical Interplay ...
# 674       675  Trust Your Neighbours: Penalty-Based Constrain...
# 675       676  Twelve-Lead ECG Reconstruction from Single-Lea...
# 676       677  UM-CAM: Uncertainty-weighted Multi-resolution ...
# 677       678  UOD: Universal One-Shot Detection of Anatomica...
# 678       679  UPCoL: Uncertainty-Informed Prototype Consiste...
# 679       680  UWAT-GAN: Fundus Fluorescein Angiography Synth...
# 680       681  UXDiff: Synthesis of X-Ray Image from Ultrasou...
# 681       682  Ultrasonic Tracking of a Rapid-Exchange Microc...
# 682       683  Uncertainty Inspired Autism Spectrum Disorder ...
# 683       684  Uncertainty and Shape-Aware Continual Test-Tim...
# 684       685  Uncertainty-Informed Mutual Learning for Joint...
# 685       686  Uncovering Heterogeneity in Alzheimers Diseas...
# 686       687  Uncovering Structural-Functional Coupling Alte...
# 687       688  Understanding Silent Failures in Medical Image...
# 688       689  UniSeg: A Prompt-Driven Universal Segmentation...
# 689       690  Unified Brain MR-Ultrasound Synthesis Using Mu...
# 690       691  Unified Surface and Volumetric Inference on Fu...
# 691       692  Unpaired Cross-Modal Interaction Learning for ...
# 692       693  Unsupervised 3D Out-of-Distribution Detection ...
# 693       694  Unsupervised 3D Registration Through Optimizat...
# 694       695  Unsupervised Classification of Congenital Inne...
# 695       696  Unsupervised Discovery of 3D Hierarchical Stru...
# 696       697  Unsupervised Domain Adaptation for Anatomical ...
# 697       698  Unsupervised Domain Transfer with Conditional ...
# 698       699  Unsupervised Learning for Feature Extraction a...
# 699       700  Utilizing Longitudinal Chest X-Rays and Report...
# ...
# 485  10.1007/978-3-031-43904-9_20              2023          5
# 486  10.1007/978-3-031-43895-0_28              2023          2
# 487  10.1007/978-3-031-43895-0_63              2023          2
# 488  10.1007/978-3-031-43993-3_32              2023          8
# 489  10.1007/978-3-031-43987-2_60              2023          6
# 490   10.1007/978-3-031-43904-9_7              2023          5
# 491  10.1007/978-3-031-43996-4_13              2023          9
# 492  10.1007/978-3-031-43996-4_31              2023          9
# 493  10.1007/978-3-031-43996-4_30              2023          9
# 494  10.1007/978-3-031-43898-1_35              2023          3
# 495   10.1007/978-3-031-43904-9_6              2023          5
# 496  10.1007/978-3-031-43895-0_42              2023          2
# 497  10.1007/978-3-031-43993-3_44              2023          8
# 498  10.1007/978-3-031-43999-5_32              2023         10
